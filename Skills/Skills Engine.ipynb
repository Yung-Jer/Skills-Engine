# %% [markdown]
# ## 1. Importing Libraries/Tools

# %%
import gensim
import multiprocessing
import nltk
import numpy as np
import pandas as pd
import re
import sklearn
import spacy
import pickle

from gensim import corpora
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from sklearn.feature_extraction import DictVectorizer
from sklearn.preprocessing import MultiLabelBinarizer
from spacy.tokenizer import Tokenizer

# %% [markdown]
# ## 2. Load Relevant Data

# %%
# load pre-trained model
nlp = spacy.load('en_core_web_sm')
# Tokenize words only with the whitespace rule
# N-grams will no longer be treated as 'N' and '-grams'
nlp.tokenizer = Tokenizer(nlp.vocab, token_match=re.compile(r'\S+').match)

skills_api = pd.read_excel('all_skills_emsi.xlsx')
skills_api['name'] = skills_api['name'].apply(lambda x: re.sub("\W?\(.*?\)","",x))
skills_api['name'] = skills_api['name'].apply(lambda x: x.strip().lower())
skills_api['lemmatized_name'] = skills_api['name'].apply(lambda x: ' '.join([token.lemma_ for token in nlp(x)]))
skills_api = set(skills_api['name']).union(set(skills_api['lemmatized_name']))

df1 = pd.read_csv('Resume.csv')
# standardise column names
df1['Text'] = df1['Resume_str']
df1 = df1[['ID','Category','Text']]

df2 = pd.read_csv('Job Description.csv')
# get only english job descriptions
df2 = df2[df2['job_post_lang'].str.lower() == 'en-gb'] 
# standardise column names
df2['ID'] = df2['uniq_id']
df2['Category'] = df2['category']
df2['Text'] = df2['job_requirements']
df2 = df2[['ID','Category','Text']]
# drop empty rows
df2 = df2.dropna().reset_index(drop=True)

# %%
df1["Category"].value_counts()
# Out:
# INFORMATION-TECHNOLOGY    120
# BUSINESS-DEVELOPMENT      120
# FINANCE                   118
# ADVOCATE                  118
# ACCOUNTANT                118
# ENGINEERING               118
# CHEF                      118
# AVIATION                  117
# FITNESS                   117
# SALES                     116
# BANKING                   115
# HEALTHCARE                115
# CONSULTANT                115
# CONSTRUCTION              112
# PUBLIC-RELATIONS          111
# HR                        110
# DESIGNER                  107
# ARTS                      103
# TEACHER                   102
# APPAREL                    97
# DIGITAL-MEDIA              96
# AGRICULTURE                63
# AUTOMOBILE                 36
# BPO                        22
# Name: Category, dtype: int64

# %%
df2["Category"].value_counts()
# Out:
# Registered Nurses                                    2513
# Personal Care Aides                                   508
# Social and Human Service Assistants                   415
# Home Health Aides                                     393
# Medical and Health Services Managers                  253
#                                                      ...
# Health Technologists and Technicians, All Other         1
# Electronics Engineering Technicians                     1
# Production Workers, All Other                           1
# Insurance Adjusters, Examiners, and Investigators       1
# Computer Network Architects                             1
# Name: Category, Length: 291, dtype: int64

# %% [markdown]
# ## 3. Skills Extraction

# %% [markdown]
# Common Skills Extraction Functions

# %%
def preprocess(txt):
    txt = txt.lower()
    # these must come first
    txt = re.sub('b\.\S*', '', txt) # remove all bachelor qualifications
    txt = re.sub('m\.\S*', '', txt) # remove all master qualifications
    # then these
    txt = txt.replace("'","").replace("’","") # remove apostrophes
    txt = re.sub('<.*?>',' ',txt) # remove <> tags
    txt = re.sub('http\S+\s*', ' ', txt)  # remove URLs
    txt = re.sub('RT|cc', ' ', txt)  # remove RT and cc
    txt = re.sub('#\S+', '', txt)  # remove hashtags
    txt = re.sub('@\S+', '  ', txt)  # remove mentions
    txt = re.sub('[^a-zA-Z]', ' ', txt) # Remove non-English characters
    txt = re.sub('\s+', ' ', txt)  # remove extra whitespace

    # tokenize word
    txt = nlp(txt)

    # remove stop words
    txt = [token.text for token in txt if not token.is_stop]

    return ' '.join(txt)

def n_grams(tokens, n):
    return [' '.join(tokens[i:i+n]) for i in range(len(tokens)-n+1)]

def generate_list_of_skills(text):
    nlp_text = nlp(text)

    # removing stop words and implementing word tokenization
    tokens = [token.text for token in nlp_text if not token.is_stop]
    # all the resume skills will be saved here
    skillset = []
        
    # check for one-grams (example: python)
    for token in tokens:
        skillset.append(token)
        
    # check for noun_chunks (example: machine learning)
    for token in nlp_text.noun_chunks:
        token = token.text.lower().strip()
        skillset.append(token)

    # check for N-grams that SpaCy missed in the noun_chuncks
    for n in range(2, 5):
        for token in n_grams(tokens, n):
            token = token.lower().strip()
            skillset.append(token)

    return skillset

# %% [markdown]
# ### 3.1 User Skills Extraction

# %% [markdown]
# Functions
#
# The following functions are used to iudentify and extract skills from a user's resume, calculate the years of experience candidate has in said skills based on the dates provided and the final result will be a dictionary where the key is the identified skill and the value is the number of years of experience the candidate has.

# %%
def section_break(original_resume_text):
    pattern = r'\b[A-Z]+\b'
    res = list(re.finditer(pattern, original_resume_text))
    ans = []

    if len(res) == 0:
        ans.append(original_resume_text)
    elif len(res) == 1:
        ans.append(original_resume_text[res[0].span()[1]:])
    else:
        i = 1
        while i < len(res):
            ans.append(original_resume_text[res[i-1].span()[1]:res[i].span()[0]])
            i += 1
        ans.append(original_resume_text[res[i-1].span()[1]:])
    return ans

def extract_skills(resume_text, skills_api, clean=True):
    if clean == True:
        resume_text = preprocess(resume_text)
    
    skillset = set([i for i in set([i.lower() for i in generate_list_of_skills(resume_text)])])
    return skillset.intersection(skills_api)

def date_search(resume):
    ans = []

    # find all the date occurrence based on the regular expression
    pattern = r'(((Jan(uary)?|Feb(ruary)?|Mar(ch)?|Apr(il)?|May|Jun(e)?|Jul(y)?|Aug(ust)?|Sep(tember)?|Nov(ember)?|Dec(ember)?)|(\d{1,2}\s?\/){0,2}|(\d{1,2}\s?\-){0,2})\s?[-/ ]?\s?\d{4}?)|\bPresent\b|\bpresent\b|\bCurrent\b|\bcurrent\b'
    res = list(re.finditer(pattern, resume))

    if len(res) > 1:
        for ele in res:
            # this is to eradicate the results of having only year but without month
            if len(ele.group().strip()) > 5:
                ans.append([ele.start(), ele.end(), ele.group().strip()])

    res = []
    # Convert "present" and "current" to today's date
    for ele in ans:
        if ele[2].lower() == 'present' or ele[2].lower() == 'current':
            today = pd.to_datetime('today').date()
            ele[2] = today
            res.append(ele)
        else:
            # catch DateParse Error here
            try:
                day = pd.to_datetime(ele[2]).date()
                ele[2] = day
                res.append(ele)
            except :
                print('Cannot parse the date: ', ele[2])

    
    # all the date results are given in the form of [datetime_start_index, datetime_end_index, datetime]
    return res

def experience_tagging(date_list):
    i = 1
    cleaned_section = {}

    while i < len(date_list):

        prev = date_list[i-1]
        cur = date_list[i]
        
        if cur[0] < prev[1] + 10:
            # Taking ceiling of the year of experience
            key = ((cur[2] - prev[2]).days // 365) + 1
            
            # section starts at the (end index of the current date) + 1
            frm = cur[1]+1

            if i < len(date_list) - 1:
                # if there is another date that appears later, then the section will be until the start index of the next date
                until = date_list[i+1][0]
            else:
                # else the section will be until the end of the resume
                until = -1
            

            # Multiple projects with same year of experience, we do 'chaining' here
            if key in cleaned_section:
                cleaned_section[key].append((frm, until))
            else:
                cleaned_section[key] = [(frm, until)]
            i += 2

        else:

            # ignore the current date, possibly it is useless
            i += 1

    return cleaned_section

def skills_experience_level_identification(resume, skills_api, clean=True):
    res = {}
    sections = section_break(resume)

    for section in sections:
        date_list = date_search(section)
        experience_sec = experience_tagging(date_list)
        for key in experience_sec:
            for start, end in experience_sec[key]:
                skills_list = extract_skills(section[start:end], skills_api, clean)
                for ele in skills_list:
                    if ele not in res:
                        res[ele] = key
                    else:
                        res[ele] = max(key, res[ele])

    # for all the skills which do not have any level of experience, assign a default value of 1
    skills_list = extract_skills(resume, skills_api, True)
    for ele in skills_list:
        if ele not in res:
            res[ele] = 1

    return dict(sorted(res.items(), key = lambda x:x[1], reverse = True))

# %% [markdown]
# Test Cases

# %%
# Test Case, Output will be a dictionary showing the skills as the key and the years of experience as the value. 
test_user = df1.iloc[300,2]
test_user_skills = skills_experience_level_identification(test_user, skills_api)
print(df1.iloc[300,1])
test_user_skills
# Out:
# INFORMATION-TECHNOLOGY
# {'operations': 18,
#  'desktop support': 1,
#  'technical support': 1,
#  'information systems': 1,
#  'coordinate': 1,
#  'management': 1,
#  'microsoft certified technology specialist': 1,
#  'network support': 1,
#  'web development': 1,
#  'security policies': 1,
#  'r': 1,
#  'streamlining': 1,
#  'adware': 1,
#  'ghost': 1,
#  'web servers': 1,
#  'virus': 1,
#  'application deployment': 1,
#  'business technology': 1,
#  'disaster recovery': 1,
#  'adobe acrobat': 1,
#  'operating systems': 1,
#  'reduction': 1,
#  'capacity planning': 1,
#  'planning': 1,
#  'windows desktop': 1,
#  'color': 1,
#  'group policy': 1,
#  'troubleshooting': 1,
#  'laser printers': 1,
#  'citrix certified administrator': 1,
#  'project management': 1,
#  'business continuity': 1,
#  'netscaler': 1,
#  'desktop environment': 1,
#  'communication': 1,
#  'active directory': 1,
#  'b': 1,
#  'laser': 1,
#  'plan': 1,
#  'spyware': 1,
#  'reliability': 1,
#  'management information systems': 1,
#  'system center configuration manager': 1,
#  'security': 1,
#  'information technology': 1}

# %%
# extract skills from all rows > store in dictionary > pickle dump
'''
df1["Skills"] = df1["Text"].apply(lambda x: skills_experience_level_identification(x,skills_api))
resume_skills0 = {}
for index, row in df1.iterrows():
  resume_skills0[row.ID] = row.Skills
with open('resume_skills.pkl', 'wb') as handle:
  pickle.dump(resume_skills0, handle)
'''
# Out:
# '\ndf1["Skills"] = df1["Text"].apply(lambda x: skills_experience_level_identification(x,skills_api))\nskills0 = {}\nfor index, row in df1.iterrows():\n  skills0[row.ID] = row.Skills\nwith open(\'user_skills.pkl\', \'wb\') as handle:\n  pickle.dump(skills0, handle)\n'

# %% [markdown]
# ### 3.2 Required Skills Extraction

# %% [markdown]
# The next portion will be to extract the skills needed for a particular job. Since there are no dates for us to parse in job descriptions, we will determine the proficiency needed for each skill by the percentage of resume/job postings having certain skills.

# %% [markdown]
# Common Functions

# %%
def find_significant_skills(agg_table):

    # gauge skill levels according to percentiles
    skills_required = {}
    for col in agg_table.columns:
        skills = agg_table[col][agg_table[col] > 0]

        # no skills extracted > skills required = empty dictionary
        if len(skills) == 0: 
            skills_required[col] = dict()
        
        # some skills extracted > skills required = some dictionary
        else:
            series = agg_table[col][agg_table[col] >= np.percentile(skills, 95)]

            # if all skills above 95th percentile have same frequency, then scale them to 1 (max)
            if len(series.unique()) == 1:
                scaled_series = series.apply(lambda x: 1)
            # if skills above 95th percentile have different frequency, then scale to values between 0 and 1
            else:
                scaled_series = series.apply(lambda x: (x - series.min()) / (series.max() - series.min()))

            # bin skills according to percentiles
            binned_series = scaled_series.apply(lambda x: 5 if x > 0.7 else 4 if x > 0.3 else 3)
            
            # convert series to dictionary form
            skills_required[col] = binned_series.to_dict()

    return skills_required

def get_significance_table(df,skills_dic):
    
    # creates a binary matrix indicating the presence of each skill
    df['Skills'] = df['ID'].apply(lambda x: list(skills_dic[x].keys()))
    mlb = MultiLabelBinarizer()
    table = pd.DataFrame(mlb.fit_transform(df['Skills']),
                         columns=mlb.classes_,
                         index=df['Skills'].index)
    
    # add category column as y
    y = df['Category']
    table['y'] = y

    # sum by category column and divide by total number of instances
    agg_table = table.groupby(['y']).sum()
    agg_table = agg_table.T / table.groupby(['y']).size()

    return agg_table

# %% [markdown]
# ##### 3.2.1 From Resume

# %% [markdown]
# Test Case

# %%
resume_df = df1.copy()

with open('resume_skills.pkl', 'rb') as pickle_file:
    resume_skills_dic = pickle.load(pickle_file)

resume_table = get_significance_table(resume_df,resume_skills_dic)
resume_table
# Out:
# y                    ACCOUNTANT  ADVOCATE  AGRICULTURE   APPAREL      ARTS  \
# abaqus                      0.0  0.000000     0.000000  0.000000  0.000000
# ablation                    0.0  0.000000     0.000000  0.000000  0.000000
# ableton live                0.0  0.000000     0.000000  0.000000  0.000000
# abnormal psychology         0.0  0.008475     0.000000  0.000000  0.000000
# absorption                  0.0  0.000000     0.015873  0.000000  0.000000
# ...                         ...       ...          ...       ...       ...
# zoning                      0.0  0.000000     0.000000  0.030928  0.000000
# zoology                     0.0  0.000000     0.000000  0.000000  0.000000
# zoom                        0.0  0.000000     0.015873  0.000000  0.000000
# zumba                       0.0  0.000000     0.000000  0.000000  0.009709
# zumba fitness               0.0  0.000000     0.000000  0.000000  0.000000
#
# y                    AUTOMOBILE  AVIATION  BANKING  BPO  BUSINESS-DEVELOPMENT  \
# abaqus                      0.0       0.0      0.0  0.0              0.000000
# ablation                    0.0       0.0      0.0  0.0              0.000000
# ableton live                0.0       0.0      0.0  0.0              0.000000
# abnormal psychology         0.0       0.0      0.0  0.0              0.000000
# absorption                  0.0       0.0      0.0  0.0              0.000000
# ...                         ...       ...      ...  ...                   ...
# zoning                      0.0       0.0      0.0  0.0              0.000000
# zoology                     0.0       0.0      0.0  0.0              0.000000
# zoom                        0.0       0.0      0.0  0.0              0.008333
# zumba                       0.0       0.0      0.0  0.0              0.000000
# zumba fitness               0.0       0.0      0.0  0.0              0.000000
#
# y                    ...  DIGITAL-MEDIA  ENGINEERING  FINANCE   FITNESS  \
# abaqus               ...       0.000000     0.016949      0.0  0.000000
# ablation             ...       0.000000     0.000000      0.0  0.000000
# ableton live         ...       0.010417     0.000000      0.0  0.000000
# abnormal psychology  ...       0.000000     0.000000      0.0  0.000000
# absorption           ...       0.000000     0.000000      0.0  0.000000
# ...                  ...            ...          ...      ...       ...
# zoning               ...       0.000000     0.000000      0.0  0.000000
# zoology              ...       0.000000     0.000000      0.0  0.000000
# zoom                 ...       0.000000     0.000000      0.0  0.008547
# zumba                ...       0.000000     0.000000      0.0  0.051282
# zumba fitness        ...       0.000000     0.000000      0.0  0.008547
#
# y                    HEALTHCARE        HR  INFORMATION-TECHNOLOGY  \
# abaqus                 0.000000  0.000000                     0.0
# ablation               0.000000  0.000000                     0.0
# ableton live           0.000000  0.000000                     0.0
# abnormal psychology    0.008696  0.009091                     0.0
# absorption             0.000000  0.000000                     0.0
# ...                         ...       ...                     ...
# zoning                 0.000000  0.000000                     0.0
# zoology                0.000000  0.000000                     0.0
# zoom                   0.000000  0.000000                     0.0
# zumba                  0.000000  0.000000                     0.0
# zumba fitness          0.000000  0.000000                     0.0
#
# y                    PUBLIC-RELATIONS     SALES   TEACHER
# abaqus                            0.0  0.000000  0.000000
# ablation                          0.0  0.008621  0.000000
# ableton live                      0.0  0.000000  0.000000
# abnormal psychology               0.0  0.000000  0.000000
# absorption                        0.0  0.000000  0.000000
# ...                               ...       ...       ...
# zoning                            0.0  0.000000  0.009804
# zoology                           0.0  0.000000  0.000000
# zoom                              0.0  0.000000  0.000000
# zumba                             0.0  0.000000  0.000000
# zumba fitness                     0.0  0.000000  0.000000
#
# [8162 rows x 24 columns]

# %%
resume_skills_required = find_significant_skills(resume_table)


with open('resume_skills_required.pkl', 'wb') as handle:
  pickle.dump(resume_skills_required, handle)


resume_skills_required
# Out:
# {'ACCOUNTANT': {'audit': 4,
#   'auditing': 3,
#   'balance': 4,
#   'balance sheet': 3,
#   'bank reconciliations': 3,
#   'banking': 3,
#   'billing': 4,
#   'bookkeeping': 3,
#   'budget': 4,
#   'budgeting': 3,
#   'business administration': 4,
#   'cash flow': 3,
#   'close': 3,
#   'closing': 4,
#   'collections': 3,
#   'communication': 4,
#   'customer service': 3,
#   'depreciation': 3,
#   'detail oriented': 3,
#   'file': 3,
#   'filing': 3,
#   'finance': 4,
#   'financial analysis': 3,
#   'financial statement': 3,
#   'financial statements': 4,
#   'forecast': 3,
#   'forecasting': 3,
#   'general ledger': 4,
#   'invoice': 3,
#   'invoicing': 3,
#   'journal': 4,
#   'leadership': 3,
#   'ledger': 5,
#   'level': 3,
#   'm': 3,
#   'management': 5,
#   'microsoft office': 4,
#   'operations': 4,
#   'organizational skills': 3,
#   'plan': 3,
#   'planning': 3,
#   'problem solving': 3,
#   'purchase': 3,
#   'quickbooks': 4,
#   'r': 3,
#   'reconciliation': 4,
#   'research': 3,
#   'sales': 4,
#   'sales tax': 3,
#   'spreadsheets': 3,
#   'tax returns': 3,
#   'time management': 3,
#   'track': 3},
#  'ADVOCATE': {'active listening': 3,
#   'advocacy': 3,
#   'billing': 3,
#   'budget': 3,
#   'business administration': 3,
#   'case management': 3,
#   'closing': 3,
#   'coach': 3,
#   'coaching': 3,
#   'collection': 3,
#   'communication': 4,
#   'communications': 3,
#   'conflict resolution': 3,
#   'coordinate': 3,
#   'coordinating': 3,
#   'crisis intervention': 3,
#   'critical thinking': 3,
#   'customer inquiries': 3,
#   'customer service': 4,
#   'data entry': 3,
#   'decision making': 3,
#   'detail oriented': 3,
#   'electronic': 3,
#   'energetic': 3,
#   'file': 3,
#   'filing': 3,
#   'floor': 3,
#   'leadership': 4,
#   'level': 4,
#   'listening skills': 3,
#   'management': 5,
#   'marketing': 3,
#   'medicare': 3,
#   'mental health': 3,
#   'merchandise': 3,
#   'microsoft excel': 3,
#   'microsoft office': 3,
#   'microsoft word': 3,
#   'nursing': 3,
#   'operation': 3,
#   'operations': 4,
#   'organizational skills': 3,
#   'paperwork': 3,
#   'plan': 4,
#   'planning': 4,
#   'presentation': 3,
#   'presentations': 3,
#   'problem solving': 3,
#   'project management': 3,
#   'psychology': 3,
#   'research': 4,
#   'resource': 3,
#   'safe': 3,
#   'sales': 4,
#   'scheduling': 3,
#   'security': 3,
#   'stock': 3,
#   'supervision': 3,
#   'teaching': 3,
#   'team building': 3,
#   'time management': 3,
#   'track': 3,
#   'tracking': 3,
#   'troubleshooting': 3,
#   'type': 3,
#   'typing': 3,
#   'writing': 3},
#  'AGRICULTURE': {'advise': 3,
#   'agriculture': 4,
#   'audit': 3,
#   'biology': 3,
#   'budget': 3,
#   'budgeting': 3,
#   'business administration': 3,
#   'c': 3,
#   'chemistry': 3,
#   'collaboration': 3,
#   'collection': 3,
#   'communication': 4,
#   'communications': 3,
#   'customer service': 3,
#   'data analysis': 3,
#   'data collection': 3,
#   'data entry': 3,
#   'economic': 3,
#   'editing': 3,
#   'electronic': 3,
#   'farm': 3,
#   'file': 3,
#   'filing': 3,
#   'finance': 3,
#   'financial management': 3,
#   'goal setting': 3,
#   'leadership': 4,
#   'level': 4,
#   'm': 3,
#   'management': 5,
#   'management system': 3,
#   'marketing': 3,
#   'merchandise': 3,
#   'microsoft office': 3,
#   'microsoft word': 3,
#   'operations': 3,
#   'plan': 4,
#   'planning': 4,
#   'presentation': 3,
#   'presentations': 3,
#   'problem solving': 3,
#   'profile': 3,
#   'programming': 3,
#   'project management': 3,
#   'public relations': 3,
#   'public speaking': 3,
#   'purchase': 3,
#   'quality assurance': 3,
#   'quality control': 3,
#   'r': 3,
#   'research': 4,
#   'resource': 3,
#   'safe': 3,
#   'sales': 3,
#   'scale': 3,
#   'security': 3,
#   'statistics': 3,
#   'storage': 3,
#   'strategic planning': 3,
#   'supervision': 3,
#   'survey': 3,
#   'surveys': 3,
#   'teaching': 3,
#   'time management': 3,
#   'tool': 3,
#   'track': 3,
#   'tracking': 3,
#   'typing': 3,
#   'write': 3,
#   'writing': 3},
#  'APPAREL': {'balancing': 3,
#   'brand': 3,
#   'budget': 3,
#   'business administration': 3,
#   'cashier': 3,
#   'close': 3,
#   'closing': 3,
#   'coaching': 3,
#   'collection': 3,
#   'color': 3,
#   'communication': 4,
#   'communications': 3,
#   'construction': 3,
#   'coordinate': 3,
#   'coordinating': 3,
#   'customer service': 4,
#   'data entry': 3,
#   'detail oriented': 3,
#   'energetic': 3,
#   'filing': 3,
#   'floor': 3,
#   'inventory control': 3,
#   'leadership': 4,
#   'level': 3,
#   'logistics': 3,
#   'management': 5,
#   'marketing': 4,
#   'merchandise': 4,
#   'merchandising': 4,
#   'microsoft office': 3,
#   'operation': 3,
#   'operations': 4,
#   'organizational skills': 3,
#   'plan': 3,
#   'planning': 4,
#   'presentation': 3,
#   'presentations': 3,
#   'problem solving': 3,
#   'profile': 3,
#   'project management': 3,
#   'purchase': 3,
#   'purchasing': 3,
#   'quality control': 3,
#   'research': 3,
#   'retail sales': 3,
#   'safe': 3,
#   'sale': 3,
#   'sales': 5,
#   'sample': 3,
#   'scheduling': 3,
#   'security': 3,
#   'social media': 3,
#   'stock': 3,
#   'supervision': 3,
#   'team building': 3,
#   'time management': 3,
#   'track': 3,
#   'tracking': 3,
#   'warehouse': 3},
#  'ARTS': {'act': 3,
#   'billing': 3,
#   'budget': 3,
#   'c': 3,
#   'cashier': 3,
#   'classroom management': 3,
#   'coach': 3,
#   'coaching': 3,
#   'collaboration': 3,
#   'collection': 3,
#   'communication': 4,
#   'communications': 3,
#   'construction': 3,
#   'coordinate': 3,
#   'coordinating': 3,
#   'customer service': 4,
#   'detail oriented': 3,
#   'energetic': 3,
#   'english language': 3,
#   'file': 3,
#   'filing': 3,
#   'finance': 3,
#   'floor': 3,
#   'fundraising': 3,
#   'grade': 3,
#   'installation': 3,
#   'language arts': 3,
#   'leadership': 4,
#   'lesson planning': 3,
#   'level': 4,
#   'literacy': 3,
#   'logistics': 3,
#   'management': 5,
#   'marketing': 4,
#   'microsoft office': 4,
#   'microsoft word': 3,
#   'operation': 3,
#   'operations': 4,
#   'organizational skills': 3,
#   'plan': 4,
#   'planning': 4,
#   'presentation': 3,
#   'presentations': 3,
#   'problem solving': 3,
#   'profile': 3,
#   'programming': 3,
#   'project management': 3,
#   'psychology': 3,
#   'public relations': 3,
#   'public speaking': 3,
#   'purchase': 3,
#   'purchasing': 3,
#   'research': 4,
#   'resource': 3,
#   'retail sales': 3,
#   'safe': 3,
#   'sales': 4,
#   'scheduling': 3,
#   'security': 3,
#   'social media': 3,
#   'spreadsheets': 3,
#   'stock': 3,
#   'storytelling': 3,
#   'supervision': 3,
#   'teach': 3,
#   'teaching': 4,
#   'team building': 3,
#   'time management': 3,
#   'track': 3,
#   'tracking': 3,
#   'writing': 4},
#  'AUTOMOBILE': {'balance': 3,
#   'banking': 3,
#   'billing': 3,
#   'budget': 3,
#   'business administration': 3,
#   'c': 3,
#   'communication': 4,
#   'coordinating': 3,
#   'customer inquiries': 3,
#   'customer service': 4,
#   'data analysis': 3,
#   'data entry': 3,
#   'database management': 3,
#   'electronic': 3,
#   'file': 3,
#   'investigation': 3,
#   'leadership': 3,
#   'level': 4,
#   'license': 3,
#   'm': 3,
#   'management': 5,
#   'marketing': 3,
#   'medical records': 3,
#   'microsoft office': 3,
#   'operation': 3,
#   'operations': 4,
#   'plan': 3,
#   'planning': 4,
#   'problem solving': 3,
#   'profile': 3,
#   'project management': 3,
#   'r': 3,
#   'repair': 3,
#   'research': 3,
#   'resource': 3,
#   'sales': 4,
#   'scheduling': 3,
#   'security': 3,
#   'spreadsheets': 3,
#   'sql': 3,
#   'supervision': 3,
#   'time management': 3,
#   'tool': 3,
#   'track': 3,
#   'tracking': 3,
#   'writing': 3},
#  'AVIATION': {'aircraft maintenance': 3,
#   'ammunition': 3,
#   'aviation': 5,
#   'b': 3,
#   'balance': 3,
#   'budget': 3,
#   'business administration': 3,
#   'c': 3,
#   'communication': 4,
#   'communications': 3,
#   'construction': 3,
#   'control systems': 3,
#   'coordinate': 3,
#   'coordinating': 3,
#   'critical thinking': 3,
#   'customer service': 4,
#   'data entry': 3,
#   'electronic': 3,
#   'electronics': 3,
#   'filing': 3,
#   'hydraulic': 3,
#   'installation': 3,
#   'inventory control': 3,
#   'inventory management': 3,
#   'leadership': 4,
#   'level': 4,
#   'license': 3,
#   'logistics': 4,
#   'm': 3,
#   'machine': 3,
#   'management': 5,
#   'marketing': 3,
#   'mechanic': 3,
#   'mechanics': 3,
#   'merchandise': 3,
#   'microsoft office': 3,
#   'microsoft word': 3,
#   'operation': 4,
#   'operations': 4,
#   'paperwork': 3,
#   'plan': 3,
#   'planning': 4,
#   'presentations': 3,
#   'problem solving': 3,
#   'process improvement': 3,
#   'procurement': 3,
#   'profile': 3,
#   'project management': 3,
#   'purchase': 3,
#   'purchasing': 3,
#   'quality assurance': 3,
#   'quality control': 3,
#   'r': 3,
#   'reduction': 3,
#   'repair': 4,
#   'repairing': 3,
#   'research': 3,
#   'resource': 3,
#   'safe': 3,
#   'safety training': 3,
#   'sales': 3,
#   'scheduling': 3,
#   'security': 4,
#   'security clearance': 3,
#   'spreadsheets': 3,
#   'stock': 3,
#   'storage': 3,
#   'supervision': 3,
#   'test equipment': 3,
#   'time management': 3,
#   'tool': 3,
#   'track': 3,
#   'tracking': 3,
#   'troubleshoot': 3,
#   'troubleshooting': 4,
#   'warehouse': 3,
#   'writing': 3},
#  'BANKING': {'act': 3,
#   'analytics': 3,
#   'audit': 3,
#   'b': 3,
#   'balance': 3,
#   'balancing': 3,
#   'banking': 5,
#   'billing': 3,
#   'book': 3,
#   'budget': 4,
#   'business administration': 3,
#   'business development': 3,
#   'c': 3,
#   'close': 3,
#   'closing': 3,
#   'coach': 3,
#   'coaching': 3,
#   'collection': 3,
#   'communication': 4,
#   'communications': 3,
#   'coordinate': 3,
#   'customer service': 4,
#   'economics': 3,
#   'electronic': 3,
#   'equity': 3,
#   'finance': 4,
#   'financial analysis': 3,
#   'financial statements': 3,
#   'forecasting': 3,
#   'investment': 3,
#   'investment banking': 3,
#   'investments': 3,
#   'leadership': 4,
#   'level': 4,
#   'loan': 4,
#   'loans': 4,
#   'm': 3,
#   'management': 5,
#   'marketing': 4,
#   'microsoft office': 3,
#   'microsoft word': 3,
#   'negotiation': 3,
#   'operation': 3,
#   'operations': 4,
#   'organizational skills': 3,
#   'plan': 3,
#   'planning': 4,
#   'presentation': 3,
#   'presentations': 3,
#   'problem solving': 3,
#   'process improvement': 3,
#   'profile': 3,
#   'project management': 3,
#   'quality assurance': 3,
#   'r': 3,
#   'real estate': 3,
#   'reconciliation': 3,
#   'research': 4,
#   'resource': 3,
#   'risk management': 3,
#   'sale': 3,
#   'sales': 5,
#   'scheduling': 3,
#   'security': 3,
#   'sql': 3,
#   'supervision': 3,
#   'time management': 3,
#   'tool': 3,
#   'track': 3,
#   'tracking': 3,
#   'underwriting': 3,
#   'write': 3,
#   'writing': 3},
#  'BPO': {'appraisal': 3,
#   'b': 3,
#   'balance': 3,
#   'budget': 3,
#   'c': 3,
#   'change management': 3,
#   'close': 3,
#   'closing': 3,
#   'coaching': 3,
#   'communication': 3,
#   'coordinate': 3,
#   'customer service': 3,
#   'file': 3,
#   'filing': 3,
#   'leadership': 4,
#   'level': 3,
#   'management': 5,
#   'marketing': 3,
#   'microsoft office': 3,
#   'operations': 4,
#   'plan': 3,
#   'planning': 4,
#   'problem solving': 3,
#   'process improvement': 3,
#   'profile': 3,
#   'purchase': 3,
#   'quality assurance': 3,
#   'research': 3,
#   'resource': 3,
#   'sales': 4,
#   'scheduling': 3,
#   'security': 3,
#   'technical support': 3,
#   'tool': 3,
#   'tracking': 3,
#   'troubleshooting': 3,
#   'type': 3},
#  'BUSINESS-DEVELOPMENT': {'act': 3,
#   'analytics': 3,
#   'banking': 3,
#   'billing': 3,
#   'brand': 3,
#   'branding': 3,
#   'budget': 4,
#   'budgeting': 3,
#   'business administration': 3,
#   'business development': 5,
#   'business development company': 3,
#   'c': 3,
#   'close': 3,
#   'closing': 3,
#   'coach': 3,
#   'coaching': 3,
#   'cold calling': 3,
#   'communication': 4,
#   'communications': 3,
#   'consulting': 3,
#   'coordinate': 3,
#   'customer relationship management': 3,
#   'customer service': 4,
#   'decision making': 3,
#   'detail oriented': 3,
#   'finance': 3,
#   'forecasting': 3,
#   'investment': 3,
#   'lead generation': 3,
#   'leadership': 4,
#   'level': 4,
#   'loan': 3,
#   'logistics': 3,
#   'm': 3,
#   'management': 5,
#   'market share': 3,
#   'marketing': 5,
#   'marketing materials': 3,
#   'marketing strategies': 3,
#   'microsoft office': 3,
#   'negotiation': 3,
#   'new business development': 3,
#   'operations': 4,
#   'plan': 4,
#   'planning': 4,
#   'presentation': 3,
#   'presentations': 4,
#   'problem solving': 3,
#   'profile': 3,
#   'project management': 3,
#   'psychology': 3,
#   'public relations': 3,
#   'purchase': 3,
#   'real estate': 3,
#   'relationship building': 3,
#   'relationship management': 3,
#   'research': 3,
#   'resource': 3,
#   'sale': 3,
#   'sales': 5,
#   'sales management': 3,
#   'sales strategy': 3,
#   'sales training': 3,
#   'salesforce': 3,
#   'scheduling': 3,
#   'security': 3,
#   'social media': 3,
#   'strategic planning': 3,
#   'team building': 3,
#   'team leadership': 3,
#   'time management': 3,
#   'track': 3,
#   'tracking': 3,
#   'writing': 3},
#  'CHEF': {'baking': 3,
#   'budget': 4,
#   'budgeting': 3,
#   'chef': 5,
#   'cleanliness': 3,
#   'coaching': 3,
#   'communication': 4,
#   'cook': 4,
#   'cooking': 4,
#   'cost control': 3,
#   'culinary arts': 4,
#   'customer service': 4,
#   'food preparation': 3,
#   'food service': 3,
#   'grill': 3,
#   'head': 3,
#   'hospitality': 3,
#   'inventory control': 3,
#   'inventory management': 3,
#   'leadership': 4,
#   'level': 3,
#   'management': 5,
#   'marketing': 3,
#   'menu planning': 3,
#   'operation': 3,
#   'operations': 4,
#   'plan': 3,
#   'planning': 3,
#   'poultry': 3,
#   'presentation': 4,
#   'problem solving': 3,
#   'profile': 3,
#   'purchasing': 3,
#   'quality control': 3,
#   'recipe': 3,
#   'recipes': 4,
#   'safe': 4,
#   'sales': 4,
#   'sanitation': 4,
#   'scheduling': 4,
#   'stock': 3,
#   'storage': 3,
#   'team building': 3,
#   'time management': 3},
#  'CONSTRUCTION': {'autocad': 3,
#   'b': 3,
#   'baseline': 3,
#   'bid': 3,
#   'bidding': 3,
#   'budget': 4,
#   'budgeting': 3,
#   'building codes': 3,
#   'c': 3,
#   'carpentry': 3,
#   'change order': 3,
#   'change orders': 3,
#   'civil engineering': 3,
#   'close': 3,
#   'closing': 3,
#   'commercial construction': 3,
#   'communication': 4,
#   'communications': 3,
#   'construction': 5,
#   'construction management': 3,
#   'coordinate': 3,
#   'coordinating': 3,
#   'cost control': 3,
#   'customer service': 3,
#   'decision making': 3,
#   'detail oriented': 3,
#   'electronic': 3,
#   'floor': 3,
#   'heavy equipment': 3,
#   'hvac': 3,
#   'installation': 3,
#   'leadership': 4,
#   'level': 3,
#   'license': 3,
#   'm': 3,
#   'management': 5,
#   'marketing': 3,
#   'microsoft office': 3,
#   'microsoft project': 3,
#   'negotiation': 3,
#   'operation': 3,
#   'operations': 4,
#   'painting': 3,
#   'plan': 3,
#   'planning': 4,
#   'plumbing': 3,
#   'problem solving': 3,
#   'procurement': 3,
#   'profile': 3,
#   'programming': 3,
#   'project management': 4,
#   'project schedules': 3,
#   'punch': 3,
#   'purchase': 3,
#   'purchasing': 3,
#   'quality assurance': 3,
#   'quality control': 3,
#   'real estate': 3,
#   'renovation': 3,
#   'repair': 3,
#   'research': 3,
#   'residential construction': 3,
#   'resource': 3,
#   'safe': 3,
#   'sales': 3,
#   'scheduling': 3,
#   'security': 3,
#   'stock': 3,
#   'submittals': 3,
#   'supervision': 3,
#   'survey': 3,
#   'team building': 3,
#   'time management': 3,
#   'tool': 3,
#   'track': 3,
#   'tracking': 3,
#   'type': 3,
#   'writing': 3},
#  'CONSULTANT': {'act': 3,
#   'active directory': 3,
#   'audit': 3,
#   'automation': 3,
#   'b': 3,
#   'balance': 3,
#   'banking': 3,
#   'billing': 3,
#   'brand': 3,
#   'budget': 3,
#   'budgeting': 3,
#   'business administration': 3,
#   'business development': 3,
#   'business process': 3,
#   'business requirements': 3,
#   'c': 3,
#   'change management': 3,
#   'close': 3,
#   'coaching': 3,
#   'collaboration': 3,
#   'communication': 4,
#   'communications': 3,
#   'computer science': 3,
#   'conflict resolution': 3,
#   'consulting': 3,
#   'coordinate': 3,
#   'customer service': 3,
#   'customer support': 3,
#   'economics': 3,
#   'electronic': 3,
#   'file': 3,
#   'filing': 3,
#   'finance': 3,
#   'financial analysis': 3,
#   'forecasting': 3,
#   'gap analysis': 3,
#   'information systems': 3,
#   'information technology': 3,
#   'installation': 3,
#   'investment': 3,
#   'java': 3,
#   'javascript': 3,
#   'journal': 3,
#   'leadership': 4,
#   'level': 4,
#   'license': 3,
#   'linux': 3,
#   'logistics': 3,
#   'm': 3,
#   'management': 5,
#   'market research': 3,
#   'marketing': 4,
#   'microsoft office': 3,
#   'mysql': 3,
#   'operating systems': 3,
#   'operation': 3,
#   'operations': 4,
#   'operations management': 3,
#   'page': 3,
#   'paperwork': 3,
#   'plan': 3,
#   'planning': 4,
#   'presentation': 3,
#   'presentations': 3,
#   'problem solving': 3,
#   'process improvement': 3,
#   'procurement': 3,
#   'profile': 3,
#   'programming': 3,
#   'project management': 4,
#   'public relations': 3,
#   'purchase': 3,
#   'purchasing': 3,
#   'quality assurance': 3,
#   'quickbooks': 3,
#   'r': 3,
#   'reconciliation': 3,
#   'reduction': 3,
#   'research': 4,
#   'resource': 3,
#   'sale': 3,
#   'sales': 4,
#   'scale': 3,
#   'scheduling': 3,
#   'security': 3,
#   'social media': 3,
#   'software development': 3,
#   'source': 3,
#   'spreadsheets': 3,
#   'sql': 3,
#   'storage': 3,
#   'strategic planning': 3,
#   'surveys': 3,
#   'team building': 3,
#   'technical support': 3,
#   'time management': 3,
#   'tool': 3,
#   'track': 3,
#   'tracking': 3,
#   'transformation': 3,
#   'troubleshoot': 3,
#   'troubleshooting': 3,
#   'unix': 3,
#   'visual basic': 3,
#   'warehouse': 3,
#   'writing': 3},
#  'DESIGNER': {'adobe creative suite': 3,
#   'adobe illustrator': 3,
#   'adobe indesign': 3,
#   'adobe photoshop': 3,
#   'applied science': 3,
#   'autocad': 3,
#   'brand': 3,
#   'branding': 3,
#   'brochures': 3,
#   'budget': 4,
#   'c': 3,
#   'collaboration': 3,
#   'color': 3,
#   'communication': 4,
#   'communications': 3,
#   'construction': 4,
#   'consulting': 3,
#   'customer service': 4,
#   'detail oriented': 3,
#   'drawing': 3,
#   'edit': 3,
#   'editing': 3,
#   'electronic': 3,
#   'fabrication': 3,
#   'file': 3,
#   'floor': 3,
#   'graphic design': 3,
#   'illustration': 3,
#   'installation': 3,
#   'interior design': 3,
#   'leadership': 4,
#   'level': 3,
#   'machine': 3,
#   'management': 5,
#   'marketing': 4,
#   'marketing materials': 3,
#   'merchandise': 3,
#   'merchandising': 3,
#   'microsoft office': 4,
#   'microsoft word': 3,
#   'multimedia': 3,
#   'operations': 3,
#   'painting': 3,
#   'photography': 3,
#   'plan': 3,
#   'planning': 4,
#   'presentation': 3,
#   'presentations': 4,
#   'problem solving': 3,
#   'profile': 3,
#   'programming': 3,
#   'project management': 3,
#   'prototype': 3,
#   'purchase': 3,
#   'purchasing': 3,
#   'quality assurance': 3,
#   'r': 3,
#   'rendering': 3,
#   'research': 4,
#   'safe': 3,
#   'sale': 3,
#   'sales': 4,
#   'scheduling': 3,
#   'security': 3,
#   'sketching': 3,
#   'social media': 3,
#   'space planning': 3,
#   'stock': 3,
#   'storage': 3,
#   'supervision': 3,
#   'templates': 3,
#   'time management': 3,
#   'track': 3,
#   'tracking': 3,
#   'typography': 3,
#   'writing': 3},
#  'DIGITAL-MEDIA': {'act': 3,
#   'adobe photoshop': 3,
#   'analytics': 4,
#   'automation': 3,
#   'b': 3,
#   'billing': 3,
#   'blog': 3,
#   'brand': 4,
#   'brand awareness': 3,
#   'branding': 3,
#   'broadcast': 3,
#   'budget': 4,
#   'budgeting': 3,
#   'business administration': 3,
#   'business development': 3,
#   'c': 3,
#   'collaboration': 3,
#   'communication': 4,
#   'communications': 4,
#   'content management': 3,
#   'content marketing': 3,
#   'coordinate': 3,
#   'customer service': 3,
#   'digital advertising': 3,
#   'digital content': 3,
#   'digital marketing': 4,
#   'digital media': 4,
#   'editing': 3,
#   'electronic': 3,
#   'email marketing': 3,
#   'facebook': 4,
#   'film': 3,
#   'final cut pro': 3,
#   'finance': 3,
#   'google analytics': 3,
#   'innovation': 3,
#   'instagram': 3,
#   'investment': 3,
#   'journalism': 3,
#   'lead generation': 3,
#   'leadership': 4,
#   'level': 3,
#   'logistics': 3,
#   'm': 3,
#   'management': 5,
#   'market research': 3,
#   'marketing': 5,
#   'marketing communications': 3,
#   'marketing strategies': 3,
#   'marketing strategy': 3,
#   'media relations': 3,
#   'media strategy': 3,
#   'microsoft office': 3,
#   'newsletters': 3,
#   'online marketing': 3,
#   'operations': 4,
#   'page': 3,
#   'pinterest': 3,
#   'plan': 4,
#   'planning': 4,
#   'presentation': 3,
#   'presentations': 3,
#   'press releases': 3,
#   'problem solving': 3,
#   'profile': 3,
#   'project management': 3,
#   'public relations': 3,
#   'relationship management': 3,
#   'research': 4,
#   'sales': 5,
#   'salesforce': 3,
#   'scheduling': 3,
#   'security': 3,
#   'social media': 4,
#   'social media marketing': 3,
#   'strategic planning': 3,
#   'team leadership': 3,
#   'time management': 3,
#   'track': 3,
#   'tracking': 3,
#   'troubleshooting': 3,
#   'wordpress': 3,
#   'writing': 3},
#  'ENGINEERING': {'autocad': 3,
#   'automation': 3,
#   'b': 3,
#   'budget': 3,
#   'business administration': 3,
#   'c': 4,
#   'calculations': 3,
#   'calibration': 3,
#   'communication': 4,
#   'communications': 3,
#   'computer science': 3,
#   'construction': 3,
#   'control systems': 3,
#   'coordinate': 3,
#   'customer service': 3,
#   'drawing': 3,
#   'electrical engineering': 3,
#   'electrical systems': 3,
#   'electronic': 3,
#   'electronics': 3,
#   'fabrication': 3,
#   'file': 3,
#   'floor': 3,
#   'hvac': 3,
#   'hydraulic': 3,
#   'installation': 3,
#   'instrumentation': 3,
#   'java': 3,
#   'labview': 3,
#   'laser': 3,
#   'leadership': 4,
#   'lean manufacturing': 3,
#   'level': 4,
#   'linux': 3,
#   'logistics': 3,
#   'm': 3,
#   'machine': 3,
#   'machinery': 3,
#   'management': 5,
#   'manufacturing engineering': 3,
#   'marketing': 3,
#   'matlab': 3,
#   'mechanical design': 3,
#   'mechanical engineering': 3,
#   'microsoft office': 3,
#   'operation': 4,
#   'operations': 4,
#   'peer': 3,
#   'physics': 3,
#   'plan': 4,
#   'planning': 4,
#   'pneumatic': 3,
#   'presentation': 3,
#   'presentations': 3,
#   'preventive maintenance': 3,
#   'problem solving': 3,
#   'process control': 3,
#   'process improvement': 3,
#   'procurement': 3,
#   'product quality': 3,
#   'production equipment': 3,
#   'profile': 3,
#   'programming': 3,
#   'project management': 4,
#   'purchase': 3,
#   'purchasing': 3,
#   'python': 3,
#   'quality assurance': 3,
#   'quality control': 3,
#   'r': 3,
#   'reduction': 3,
#   'reliability': 3,
#   'repair': 3,
#   'research': 3,
#   'resource': 3,
#   'root': 3,
#   'root cause analysis': 3,
#   'safe': 3,
#   'sales': 3,
#   'scale': 3,
#   'scheduling': 3,
#   'scrum': 3,
#   'security': 3,
#   'sensors': 3,
#   'simulation': 3,
#   'software development': 3,
#   'software engineering': 3,
#   'soldering': 3,
#   'solidworks': 3,
#   'source': 3,
#   'sql': 3,
#   'statistics': 3,
#   'storage': 3,
#   'strategic planning': 3,
#   'supervision': 3,
#   'supply chain': 3,
#   'systems engineering': 3,
#   'technical support': 3,
#   'test equipment': 3,
#   'time management': 3,
#   'tool': 3,
#   'track': 3,
#   'tracking': 3,
#   'troubleshoot': 3,
#   'troubleshooting': 3,
#   'welding': 3,
#   'write': 3,
#   'writing': 3},
#  'FINANCE': {'audit': 4,
#   'auditing': 3,
#   'balance': 3,
#   'balance sheet': 3,
#   'banking': 3,
#   'billing': 3,
#   'budget': 4,
#   'budgeting': 4,
#   'business administration': 3,
#   'c': 3,
#   'cash flow': 3,
#   'cash management': 3,
#   'close': 3,
#   'closing': 3,
#   'collection': 3,
#   'collections': 3,
#   'communication': 4,
#   'communications': 3,
#   'coordinate': 3,
#   'customer service': 3,
#   'decision making': 3,
#   'detail oriented': 3,
#   'filing': 3,
#   'finance': 5,
#   'financial analysis': 3,
#   'financial management': 3,
#   'financial planning': 3,
#   'financial statement': 3,
#   'financial statements': 3,
#   'forecast': 3,
#   'forecasting': 4,
#   'general ledger': 3,
#   'internal controls': 3,
#   'investment': 3,
#   'invoice': 3,
#   'journal': 3,
#   'leadership': 4,
#   'ledger': 3,
#   'level': 3,
#   'loan': 3,
#   'm': 3,
#   'management': 5,
#   'marketing': 3,
#   'microsoft office': 3,
#   'operation': 3,
#   'operations': 4,
#   'plan': 3,
#   'planning': 4,
#   'presentations': 3,
#   'problem solving': 3,
#   'process improvement': 3,
#   'procurement': 3,
#   'profile': 3,
#   'project management': 3,
#   'purchase': 3,
#   'purchasing': 3,
#   'quickbooks': 3,
#   'r': 3,
#   'reconciliation': 4,
#   'research': 3,
#   'resource': 3,
#   'sales': 4,
#   'strategic planning': 3,
#   'time management': 3,
#   'track': 3,
#   'tracking': 3,
#   'variance analysis': 3},
#  'FITNESS': {'anatomy': 3,
#   'athletic': 3,
#   'balance': 3,
#   'billing': 3,
#   'brand': 3,
#   'budget': 3,
#   'business administration': 3,
#   'cleanliness': 3,
#   'closing': 3,
#   'coach': 3,
#   'coaching': 3,
#   'communication': 4,
#   'communications': 3,
#   'conflict resolution': 3,
#   'coordinate': 3,
#   'customer service': 4,
#   'electronic': 3,
#   'energetic': 3,
#   'exercise programs': 3,
#   'exercise science': 3,
#   'filing': 3,
#   'floor': 3,
#   'head': 3,
#   'leadership': 4,
#   'level': 4,
#   'license': 3,
#   'm': 3,
#   'management': 5,
#   'marketing': 4,
#   'merchandise': 3,
#   'microsoft office': 3,
#   'microsoft word': 3,
#   'operation': 3,
#   'operations': 4,
#   'organizational skills': 3,
#   'paperwork': 3,
#   'plan': 3,
#   'planning': 3,
#   'presentation': 3,
#   'presentations': 3,
#   'problem solving': 3,
#   'programming': 3,
#   'project management': 3,
#   'psychology': 3,
#   'purchase': 3,
#   'research': 3,
#   'resource': 3,
#   'safe': 3,
#   'sales': 5,
#   'scheduling': 3,
#   'security': 3,
#   'social media': 3,
#   'sports medicine': 3,
#   'stock': 3,
#   'supervision': 3,
#   'teach': 3,
#   'teaching': 3,
#   'team building': 3,
#   'time management': 3,
#   'track': 3,
#   'tracking': 3},
#  'HEALTHCARE': {'act': 3,
#   'administrative support': 3,
#   'audit': 3,
#   'billing': 3,
#   'brand': 3,
#   'budget': 3,
#   'budgeting': 3,
#   'business administration': 3,
#   'business development': 3,
#   'business operations': 3,
#   'c': 3,
#   'case management': 3,
#   'closing': 3,
#   'collaboration': 3,
#   'collection': 3,
#   'communication': 4,
#   'communications': 3,
#   'consulting': 3,
#   'coordinate': 3,
#   'coordinating': 3,
#   'critical thinking': 3,
#   'customer service': 4,
#   'data analysis': 3,
#   'data entry': 3,
#   'decision making': 3,
#   'detail oriented': 3,
#   'electronic': 3,
#   'filing': 3,
#   'finance': 3,
#   'floor': 3,
#   'information systems': 3,
#   'information technology': 3,
#   'leadership': 4,
#   'level': 4,
#   'license': 3,
#   'm': 3,
#   'managed care': 3,
#   'management': 5,
#   'marketing': 3,
#   'medicaid': 3,
#   'medical record': 3,
#   'medical records': 3,
#   'medical terminology': 3,
#   'medicare': 3,
#   'merchandise': 3,
#   'microsoft office': 4,
#   'microsoft word': 3,
#   'nursing': 3,
#   'operation': 3,
#   'operations': 4,
#   'paperwork': 3,
#   'pharmaceutical': 3,
#   'plan': 3,
#   'planning': 4,
#   'presentations': 3,
#   'primary care': 3,
#   'problem solving': 3,
#   'process improvement': 3,
#   'profile': 3,
#   'project management': 3,
#   'quality assurance': 3,
#   'regulatory compliance': 3,
#   'research': 3,
#   'resource': 3,
#   'safe': 3,
#   'sales': 4,
#   'scheduling': 3,
#   'security': 3,
#   'statistics': 3,
#   'strategic planning': 3,
#   'supervision': 3,
#   'surgery': 3,
#   'teaching': 3,
#   'time management': 3,
#   'track': 3,
#   'tracking': 3,
#   'troubleshooting': 3,
#   'writing': 3},
#  'HR': {'ada': 3,
#   'administrative support': 3,
#   'audit': 3,
#   'benefits administration': 3,
#   'budget': 3,
#   'business administration': 3,
#   'coaching': 3,
#   'communication': 4,
#   'communications': 3,
#   'conflict resolution': 3,
#   'coordinate': 3,
#   'coordinating': 3,
#   'customer service': 4,
#   'disability': 3,
#   'employee benefits': 3,
#   'employee engagement': 3,
#   'employee relations': 4,
#   'file': 3,
#   'filing': 3,
#   'finance': 3,
#   'human resource management': 3,
#   'job descriptions': 3,
#   'labor relations': 3,
#   'leadership': 4,
#   'level': 4,
#   'management': 5,
#   'marketing': 3,
#   'microsoft office': 3,
#   'new hire orientation': 3,
#   'operations': 4,
#   'organizational development': 3,
#   'paperwork': 3,
#   'performance management': 4,
#   'plan': 3,
#   'planning': 4,
#   'presentation': 3,
#   'presentations': 3,
#   'problem solving': 3,
#   'project management': 3,
#   'research': 3,
#   'resource': 4,
#   'resource management': 3,
#   'sales': 3,
#   'scheduling': 3,
#   'security': 3,
#   'spreadsheets': 3,
#   'survey': 3,
#   'surveys': 3,
#   'time management': 3,
#   'track': 3,
#   'tracking': 4,
#   'writing': 3},
#  'INFORMATION-TECHNOLOGY': {'act': 3,
#   'active directory': 4,
#   'application development': 3,
#   'audit': 3,
#   'automation': 3,
#   'billing': 3,
#   'budget': 4,
#   'budgeting': 3,
#   'business administration': 3,
#   'business continuity': 3,
#   'business process': 3,
#   'business requirements': 3,
#   'c': 3,
#   'change management': 3,
#   'collaboration': 3,
#   'collection': 3,
#   'communication': 4,
#   'communications': 3,
#   'computer science': 3,
#   'computer systems': 3,
#   'consulting': 3,
#   'coordinate': 3,
#   'coordinating': 3,
#   'customer service': 3,
#   'customer support': 3,
#   'data analysis': 3,
#   'desktop support': 3,
#   'detail oriented': 3,
#   'disaster recovery': 3,
#   'document management': 3,
#   'electronic': 3,
#   'electronics': 3,
#   'file': 3,
#   'finance': 3,
#   'firewall': 3,
#   'ghost': 3,
#   'governance': 3,
#   'information assurance': 3,
#   'information systems': 4,
#   'information technology': 5,
#   'installation': 4,
#   'intranet': 3,
#   'java': 3,
#   'leadership': 4,
#   'level': 4,
#   'linux': 3,
#   'm': 3,
#   'management': 5,
#   'management information systems': 3,
#   'management system': 3,
#   'management systems': 3,
#   'marketing': 3,
#   'microsoft office': 3,
#   'microsoft windows': 3,
#   'mysql': 3,
#   'network administration': 3,
#   'network infrastructure': 3,
#   'network security': 3,
#   'operating system': 3,
#   'operating systems': 3,
#   'operation': 3,
#   'operations': 4,
#   'page': 3,
#   'php': 3,
#   'plan': 4,
#   'planning': 4,
#   'presentations': 3,
#   'problem solving': 3,
#   'process improvement': 3,
#   'procurement': 3,
#   'profile': 3,
#   'programming': 3,
#   'project management': 4,
#   'purchasing': 3,
#   'quality assurance': 3,
#   'r': 3,
#   'reliability': 3,
#   'repair': 3,
#   'research': 3,
#   'resource': 3,
#   'risk management': 3,
#   'sales': 3,
#   'scheduling': 3,
#   'security': 5,
#   'software development': 3,
#   'sql': 4,
#   'storage': 3,
#   'strategic planning': 3,
#   'supervision': 3,
#   'team building': 3,
#   'technical support': 3,
#   'telecommunications': 3,
#   'tool': 3,
#   'track': 3,
#   'tracking': 3,
#   'troubleshoot': 3,
#   'troubleshooting': 4,
#   'unix': 3,
#   'virus': 3,
#   'visual basic': 3,
#   'warehouse': 3,
#   'web development': 3,
#   'writing': 3},
#  'PUBLIC-RELATIONS': {'adobe photoshop': 3,
#   'analytics': 3,
#   'b': 3,
#   'blogs': 3,
#   'brand': 4,
#   'brand awareness': 3,
#   'branding': 3,
#   'broadcast': 3,
#   'brochures': 3,
#   'budget': 4,
#   'communication': 5,
#   'communications': 4,
#   'coordinate': 3,
#   'coordinating': 3,
#   'corporate communications': 3,
#   'customer service': 3,
#   'editing': 3,
#   'electronic': 3,
#   'event planning': 3,
#   'facebook': 3,
#   'finance': 3,
#   'fundraising': 3,
#   'graphic design': 3,
#   'journal': 3,
#   'journalism': 3,
#   'leadership': 4,
#   'level': 3,
#   'logistics': 3,
#   'm': 3,
#   'management': 5,
#   'market research': 3,
#   'marketing': 5,
#   'marketing communications': 3,
#   'marketing materials': 3,
#   'marketing strategies': 3,
#   'media coverage': 3,
#   'media relations': 3,
#   'microsoft office': 4,
#   'newsletter': 3,
#   'newsletters': 3,
#   'operations': 3,
#   'page': 3,
#   'plan': 3,
#   'planning': 4,
#   'presentation': 3,
#   'presentations': 3,
#   'press releases': 4,
#   'problem solving': 3,
#   'profile': 3,
#   'project management': 3,
#   'public relations': 5,
#   'public relations campaigns': 3,
#   'r': 3,
#   'research': 4,
#   'resource': 3,
#   'sales': 4,
#   'scheduling': 3,
#   'security': 3,
#   'social media': 4,
#   'strategic planning': 3,
#   'timelines': 3,
#   'track': 3,
#   'tracking': 3,
#   'write': 3,
#   'writing': 4},
#  'SALES': {'billing': 3,
#   'brand': 3,
#   'budget': 3,
#   'cash handling': 3,
#   'cash register': 3,
#   'cashier': 3,
#   'close': 3,
#   'closing': 3,
#   'communication': 4,
#   'communications': 3,
#   'construction': 3,
#   'customer inquiries': 3,
#   'customer service': 5,
#   'detail oriented': 3,
#   'energetic': 3,
#   'filing': 3,
#   'floor': 3,
#   'inventory control': 3,
#   'leadership': 3,
#   'level': 3,
#   'management': 5,
#   'marketing': 4,
#   'merchandise': 4,
#   'merchandising': 3,
#   'microsoft office': 3,
#   'operation': 3,
#   'operations': 3,
#   'organizational skills': 3,
#   'plan': 3,
#   'planning': 3,
#   'presentation': 3,
#   'presentations': 3,
#   'problem solving': 3,
#   'product knowledge': 3,
#   'project management': 3,
#   'purchase': 3,
#   'purchasing': 3,
#   'relationship building': 3,
#   'research': 3,
#   'retail sales': 3,
#   'safe': 3,
#   'sale': 3,
#   'sales': 5,
#   'scheduling': 3,
#   'security': 3,
#   'stock': 3,
#   'storage': 3,
#   'supervision': 3,
#   'time management': 3,
#   'track': 3,
#   'writing': 3},
#  'TEACHER': {'child development': 3,
#   'classroom management': 4,
#   'coach': 3,
#   'collaboration': 3,
#   'communication': 5,
#   'critical thinking': 3,
#   'customer service': 3,
#   'differentiated instruction': 3,
#   'disabilities': 3,
#   'early childhood education': 3,
#   'energetic': 3,
#   'grade': 4,
#   'head': 3,
#   'language arts': 3,
#   'leadership': 4,
#   'learning styles': 3,
#   'lesson planning': 3,
#   'level': 4,
#   'license': 3,
#   'literacy': 3,
#   'management': 5,
#   'marketing': 3,
#   'mathematics': 3,
#   'microsoft office': 3,
#   'operations': 3,
#   'organizational skills': 3,
#   'plan': 4,
#   'planning': 4,
#   'positive reinforcement': 3,
#   'presentations': 3,
#   'problem solving': 3,
#   'psychology': 3,
#   'reinforcement': 3,
#   'research': 3,
#   'resource': 3,
#   'safe': 3,
#   'sales': 3,
#   'scheduling': 3,
#   'security': 3,
#   'social development': 3,
#   'social skills': 3,
#   'social studies': 3,
#   'special education': 3,
#   'teach': 3,
#   'teaching': 5,
#   'time management': 3,
#   'track': 3,
#   'writing': 3}}

# %% [markdown]
# ##### 3.2.2 From Job Descriptions

# %% [markdown]
# Functions

# %%
def extract_skills_frequency(job_text, skills_api, clean=True):
  if clean == True:
      job_text = preprocess(job_text)

  # get all skills
  skillset = [i.lower() for i in generate_list_of_skills(job_text)]

  # get frequency of each skill
  skillset_count = {}
  for skill in skillset:
    if skill in skills_api:
      if skill in skillset_count:
        skillset_count[skill] = skillset_count[skill] + 1
      else:
        skillset_count[skill] = 1
  
  return dict(sorted(skillset_count.items(), key = lambda x:x[1], reverse = True))

# %% [markdown]
# Test Cases

# %%
test_job = df2.iloc[13,2]
test_job_skills = extract_skills_frequency(test_job,skills_api,True)
print(df2.iloc[13,1])
test_job_skills
# Out:
# Software Developers, Applications
# {'management': 3,
#  'c': 2,
#  'security': 2,
#  'software module': 2,
#  'programming': 1,
#  'linux': 1,
#  'collaboration': 1,
#  'software development': 1,
#  'architectural patterns': 1,
#  'configuration management': 1,
#  'requirements management': 1,
#  'cyber security': 1,
#  'software engineering': 1,
#  'technical design': 1,
#  'software development methodologies': 1,
#  'software configuration management': 1}

# %%
# extract skills from all rows > store in dictionary > pickle dump
'''
df2["Skills"] = df2["Text"].apply(lambda x: extract_skills_frequency(x,skills_api,True))
job_skills0 = {}
for index, row in df2.iterrows():
  job_skills0[row.ID] = row.Skills
with open('job_skills.pkl', 'wb') as handle:
  pickle.dump(job_skills0, handle)
'''

# %%
job_df = df2.copy()

with open('job_skills.pkl', 'rb') as pickle_file:
    job_skills_dic = pickle.load(pickle_file)

job_table = get_significance_table(job_df,job_skills_dic)
job_table
# Out:
# y                   Accountants  Actuaries  Acute Care Nurses  \
# abdomen                     0.0        0.0                0.0
# absorption                  0.0        0.0                0.0
# academic standards          0.0        0.0                0.0
# acoustic                    0.0        0.0                0.0
# acoustics                   0.0        0.0                0.0
# ...                         ...        ...                ...
# yoga                        0.0        0.0                0.0
# zone                        0.0        0.0                0.0
# zoning                      0.0        0.0                0.0
# zoology                     0.0        0.0                0.0
# zurb foundation             0.0        0.0                0.0
#
# y                   Administrative Law Judges, Adjudicators, and Hearing Officers  \
# abdomen                                                           0.0
# absorption                                                        0.0
# academic standards                                                0.0
# acoustic                                                          0.0
# acoustics                                                         0.0
# ...                                                               ...
# yoga                                                              0.0
# zone                                                              0.0
# zoning                                                            0.0
# zoology                                                           0.0
# zurb foundation                                                   0.0
#
# y                   Administrative Services Managers  \
# abdomen                                          0.0
# absorption                                       0.0
# academic standards                               0.0
# acoustic                                         0.0
# acoustics                                        0.0
# ...                                              ...
# yoga                                             0.0
# zone                                             0.0
# zoning                                           0.0
# zoology                                          0.0
# zurb foundation                                  0.0
#
# y                   Advanced Practice Psychiatric Nurses  \
# abdomen                                              0.0
# absorption                                           0.0
# academic standards                                   0.0
# acoustic                                             0.0
# acoustics                                            0.0
# ...                                                  ...
# yoga                                                 0.0
# zone                                                 0.0
# zoning                                               0.0
# zoology                                              0.0
# zurb foundation                                      0.0
#
# y                   Advertising Sales Agents  \
# abdomen                             0.000000
# absorption                          0.000000
# academic standards                  0.000000
# acoustic                            0.000000
# acoustics                           0.000000
# ...                                      ...
# yoga                                0.000000
# zone                                0.333333
# zoning                              0.000000
# zoology                             0.000000
# zurb foundation                     0.000000
#
# y                   Advertising and Promotions Managers  Aerospace Engineers  \
# abdomen                                             0.0                  0.0
# absorption                                          0.0                  0.0
# academic standards                                  0.0                  0.0
# acoustic                                            0.0                  0.0
# acoustics                                           0.0                  0.0
# ...                                                 ...                  ...
# yoga                                                0.0                  0.0
# zone                                                0.0                  0.0
# zoning                                              0.0                  0.0
# zoology                                             0.0                  0.0
# zurb foundation                                     0.0                  0.0
#
# y                   Anesthesiologists  ...  Telemarketers  \
# abdomen                           0.0  ...            0.0
# absorption                        0.0  ...            0.0
# academic standards                0.0  ...            0.0
# acoustic                          0.0  ...            0.0
# acoustics                         0.0  ...            0.0
# ...                               ...  ...            ...
# yoga                              0.0  ...            0.0
# zone                              0.0  ...            0.0
# zoning                            0.0  ...            0.0
# zoology                           0.0  ...            0.0
# zurb foundation                   0.0  ...            0.0
#
# y                   Training and Development Managers  \
# abdomen                                           0.0
# absorption                                        0.0
# academic standards                                0.0
# acoustic                                          0.0
# acoustics                                         0.0
# ...                                               ...
# yoga                                              0.0
# zone                                              0.0
# zoning                                            0.0
# zoology                                           0.0
# zurb foundation                                   0.0
#
# y                   Training and Development Specialists  \
# abdomen                                              0.0
# absorption                                           0.0
# academic standards                                   0.0
# acoustic                                             0.0
# acoustics                                            0.0
# ...                                                  ...
# yoga                                                 0.0
# zone                                                 0.0
# zoning                                               0.0
# zoology                                              0.0
# zurb foundation                                      0.0
#
# y                   Treasurers and Controllers  Tutors  Upholsterers  \
# abdomen                                    0.0     0.0           0.0
# absorption                                 0.0     0.0           0.0
# academic standards                         0.0     0.0           0.0
# acoustic                                   0.0     0.0           0.0
# acoustics                                  0.0     0.0           0.0
# ...                                        ...     ...           ...
# yoga                                       0.0     0.0           0.0
# zone                                       0.0     0.0           0.0
# zoning                                     0.0     0.0           0.0
# zoology                                    0.0     0.0           0.0
# zurb foundation                            0.0     0.0           0.0
#
# y                   Veterinary Technologists and Technicians  \
# abdomen                                                  0.0
# absorption                                               0.0
# academic standards                                       0.0
# acoustic                                                 0.0
# acoustics                                                0.0
# ...                                                      ...
# yoga                                                     0.0
# zone                                                     0.0
# zoning                                                   0.0
# zoology                                                  0.0
# zurb foundation                                          0.0
#
# y                   Vocational Education Teachers, Postsecondary  \
# abdomen                                                      0.0
# absorption                                                   0.0
# academic standards                                           0.0
# acoustic                                                     0.0
# acoustics                                                    0.0
# ...                                                          ...
# yoga                                                         0.0
# zone                                                         0.0
# zoning                                                       0.0
# zoology                                                      0.0
# zurb foundation                                              0.0
#
# y                   Waiters and Waitresses  Web Developers
# abdomen                                0.0        0.000000
# absorption                             0.0        0.000000
# academic standards                     0.0        0.000000
# acoustic                               0.0        0.000000
# acoustics                              0.0        0.000000
# ...                                    ...             ...
# yoga                                   0.0        0.000000
# zone                                   0.0        0.000000
# zoning                                 0.0        0.000000
# zoology                                0.0        0.000000
# zurb foundation                        0.0        0.022222
#
# [3068 rows x 291 columns]

# %% [markdown]
# The output below is a dictionary where the key is the role the candidate is seeking and the value tagged to it is a dictionary with the required skill as the key and the proficiency level tagged as the value. Since the courses dataset that is explored further on has a competency level of either 3, 4 or 5, all proficiency levels will either be 3, 4 or 5 to ease comparision of skills gap.

# %%
job_skills_required = find_significant_skills(job_table)


# with open('job_skills_required.pkl', 'wb') as handle:
#   pickle.dump(job_skills_required, handle)


job_skills_required
# Out:
# {'Accountants': {'audit': 3,
#   'communication': 5,
#   'finance': 4,
#   'management': 4},
#  'Actuaries': {'actuarial exams': 5,
#   'communication': 5,
#   'covenant': 5,
#   'investment': 5},
#  'Acute Care Nurses': {'management': 5,
#   'nursing': 3,
#   'planning': 3,
#   'registration': 3,
#   'rehabilitation': 3,
#   'scheme': 4},
#  'Administrative Law Judges, Adjudicators, and Hearing Officers': {'advise': 5,
#   'comment': 5,
#   'management': 5,
#   'triage': 5},
#  'Administrative Services Managers': {'c': 5,
#   'customer engagement': 5,
#   'customer service': 5,
#   'grade': 5,
#   'head': 5,
#   'procurement': 5,
#   'scheme': 5},
#  'Advanced Practice Psychiatric Nurses': {'act': 4,
#   'mental health': 5,
#   'rehabilitation': 3,
#   'supervision': 3},
#  'Advertising Sales Agents': {'b': 5, 'sales': 5},
#  'Advertising and Promotions Managers': {'brand': 5,
#   'brand identity': 5,
#   'budget': 5,
#   'facebook': 5,
#   'licensing': 5,
#   'linkedin': 5,
#   'management': 5,
#   'marketing': 5,
#   'marketing copy': 5,
#   'merchandise': 5,
#   'planning': 5,
#   'profile': 5,
#   'promotional materials': 5,
#   'promotional merchandise': 5,
#   'purchase': 5,
#   'purchasing': 5,
#   'sales': 5,
#   'social media': 5,
#   'social media campaigns': 5,
#   'tracking': 5,
#   'write': 5,
#   'writing': 5,
#   'written english': 5},
#  'Aerospace Engineers': {'act': 5,
#   'advise': 3,
#   'aerodynamic': 3,
#   'aerospace industry': 3,
#   'algorithm': 3,
#   'algorithms': 3,
#   'application datum': 3,
#   'arduino': 3,
#   'blend learning': 3,
#   'c': 3,
#   'composite': 3,
#   'computer literacy': 3,
#   'computer science': 3,
#   'computer systems': 3,
#   'control engineering': 3,
#   'control system': 3,
#   'control systems': 3,
#   'data analysis': 3,
#   'dimensioning': 3,
#   'engineering analysis': 3,
#   'engineering drawings': 3,
#   'experience design': 3,
#   'geometry': 3,
#   'installation': 3,
#   'java': 3,
#   'javascript': 3,
#   'literacy': 3,
#   'm': 3,
#   'management': 3,
#   'matlab': 3,
#   'mechanics': 3,
#   'microsoft office': 3,
#   'physics': 3,
#   'programming': 3,
#   'python': 3,
#   'raspberry pi': 3,
#   'recruitment tool': 3,
#   'report writing': 3,
#   'simulations': 3,
#   'simulink': 3,
#   'spacecraft': 3,
#   'swift': 3,
#   'tolerance analysis': 3,
#   'tool': 3,
#   'writing': 3,
#   'written english': 3},
#  'Anesthesiologists': {'management': 5},
#  'Architects, Except Landscape and Naval': {'planning': 5, 'scale': 5},
#  'Architectural Drafters': {'autocad': 5},
#  'Architectural and Engineering Managers': {'communication': 5,
#   'construction': 5,
#   'management': 5},
#  'Assemblers and Fabricators, All Other': {'drawing': 5,
#   'engineering drawings': 5,
#   'hand tools': 5,
#   'level': 5,
#   'production schedule': 5,
#   'surface': 5},
#  'Assessors': {'disability': 5},
#  'Audio and Video Equipment Technicians': {'digital imaging': 5,
#   'digital media': 5,
#   'edit': 5,
#   'electronic': 5,
#   'investigation': 5,
#   'loan': 5,
#   'photography': 5,
#   'prosecution': 5},
#  'Audiologists': {'act': 3, 'audiology': 3, 'rehabilitation': 5},
#  'Auditors': {'audit': 5, 'management': 5},
#  'Automotive Master Mechanics': {'customer service': 5,
#   'energetic': 5,
#   'fabrication': 5,
#   'head': 5,
#   'leadership': 5,
#   'repair': 5,
#   'repairing': 5,
#   'track': 5,
#   'welding': 5},
#  'Automotive Specialty Technicians': {'brand': 5, 'repair': 5},
#  'Baggage Porters and Bellhops': {'communication': 5,
#   'customer service': 5,
#   'security': 5},
#  'Bill and Account Collectors': {'collection': 3,
#   'collections': 3,
#   'communication': 5,
#   'credit control': 3,
#   'level': 3,
#   'negotiation': 3},
#  'Biochemists and Biophysicists': {'biochemistry': 5, 'immunoassay': 5},
#  'Biological Technicians': {'biology': 5, 'research': 5},
#  'Biomedical Engineers': {'commissioning': 5,
#   'diplomacy': 5,
#   'electronics': 5,
#   'incubators': 5,
#   'level': 5,
#   'management': 5,
#   'medical equipment': 5,
#   'patient monitoring': 5,
#   'planned maintenance': 5,
#   'safe': 5,
#   'transparency': 5},
#  'Bookkeeping, Accounting, and Auditing Clerks': {'communication': 4,
#   'finance': 5,
#   'purchase': 3},
#  'Bus Drivers, Transit and Intercity': {},
#  'Bus and Truck Mechanics and Diesel Engine Specialists': {'aftersales': 5,
#   'coach': 5,
#   'customer service': 5,
#   'diagnostic tests': 5,
#   'machinery': 5,
#   'manual handling': 5,
#   'mechanic': 5,
#   'paperwork': 5,
#   'physical fitness': 5,
#   'plan': 5,
#   'problem solving': 5,
#   'repair': 5,
#   'teamwork': 5,
#   'towing': 5},
#  'Business Intelligence Analysts': {'power bi': 5, 'sql': 5},
#  'Business Operations Specialists, All Other': {'act': 3,
#   'business development': 3,
#   'c': 3,
#   'close': 3,
#   'communication': 4,
#   'consulting': 3,
#   'level': 3,
#   'management': 5,
#   'operations': 3,
#   'presentation': 3,
#   'sales': 3},
#  'Cardiovascular Technologists and Technicians': {'angiography': 5,
#   'cardiac rhythm': 5,
#   'cardiology': 5,
#   'cardioversion': 5,
#   'coordinate': 5,
#   'level': 5,
#   'management': 5,
#   'nice': 5,
#   'nursing': 5,
#   'percutaneous coronary intervention': 5,
#   'perfusion': 5},
#  'Cashiers': {'act': 5,
#   'financial data': 5,
#   'international laws': 5,
#   'retail experience': 5,
#   'sales': 5,
#   'sales principles': 5,
#   'tax compliance': 5},
#  'Chefs and Head Cooks': {'chef': 5, 'hygiene': 5, 'level': 3},
#  'Chemical Technicians': {'analytical techniques': 5,
#   'annual reports': 5,
#   'chemistry': 5,
#   'cleaning validation': 5,
#   'pharmaceutical': 5,
#   'plan': 5,
#   'quality control': 5,
#   'validation master plan': 5,
#   'writing': 5},
#  'Chemists': {'chemistry': 5, 'communication': 5, 'level': 5},
#  'Chief Executives': {'agenda': 3,
#   'appraisal': 3,
#   'communication': 3,
#   'leadership': 5,
#   'management': 3,
#   'microbiology': 3,
#   'phe': 3,
#   'public health': 3,
#   'research': 3,
#   'strategic leadership': 3},
#  'Child, Family, and School Social Workers': {'child protection': 3,
#   'management': 3,
#   'social work': 5,
#   'supervision': 3},
#  'Childcare Workers': {'head': 5, 'head start': 5, 'level': 3},
#  'Civil Engineering Technicians': {'autocad': 5,
#   'construction': 5,
#   'technical design': 5},
#  'Civil Engineers': {'construction': 5, 'management': 5},
#  'Clergy': {'act': 5,
#   'close': 5,
#   'collaboration': 5,
#   'communication': 5,
#   'compassion': 5,
#   'disability': 5,
#   'emotional stamina': 5,
#   'innovation': 5,
#   'mental health': 5,
#   'registration': 5,
#   'rehabilitation': 5,
#   'transparency': 5},
#  'Clinical Nurse Specialists': {'act': 3,
#   'communication': 4,
#   'dementia': 3,
#   'leadership': 4,
#   'level': 4,
#   'management': 5,
#   'mental health': 3,
#   'nursing': 5,
#   'nursing care': 3,
#   'registered nurse': 3,
#   'registration': 3,
#   'rehabilitation': 3,
#   'safe': 3,
#   'supervision': 3},
#  'Clinical Psychologists': {'act': 3,
#   'clinical psychology': 3,
#   'management': 3,
#   'mental health': 5,
#   'psychology': 5,
#   'rehabilitation': 3,
#   'research': 4,
#   'supervision': 5,
#   'teaching': 3},
#  'Clinical Research Coordinators': {'act': 3,
#   'clinical research': 4,
#   'clinical trial': 3,
#   'clinical trials': 3,
#   'communication': 4,
#   'management': 3,
#   'rehabilitation': 3,
#   'research': 5},
#  'Community and Social Service Specialists, All Other': {'disabilities': 3,
#   'learning disabilities': 3,
#   'mental health': 3,
#   'supervision': 5},
#  'Compensation and Benefits Managers': {},
#  'Compensation, Benefits, and Job Analysis Specialists': {'communication': 5,
#   'level': 5,
#   'operations': 5},
#  'Compliance Managers': {'communication': 3, 'management': 5},
#  'Compliance Officers': {'legislation': 5},
#  'Computer Network Architects': {'control system': 5,
#   'information technology': 5,
#   'management': 5,
#   'management systems': 5,
#   'stock': 5,
#   'stock control': 5,
#   'tracking': 5},
#  'Computer Programmers': {'c': 5,
#   'communication': 3,
#   'javascript': 3,
#   'sql': 3},
#  'Computer Systems Analysts': {'communication': 4,
#   'finance': 3,
#   'level': 4,
#   'management': 3,
#   'sql': 5,
#   'warehouse': 3},
#  'Computer Systems Engineers/Architects': {'adoption': 3,
#   'c': 3,
#   'communication': 5,
#   'devops': 4,
#   'javascript': 3,
#   'level': 4,
#   'management': 5,
#   'scale': 4,
#   'software development': 3},
#  'Computer User Support Specialists': {'active directory': 3,
#   'communication': 5,
#   'customer service': 4,
#   'customer support': 3,
#   'level': 5,
#   'management': 4,
#   'operating systems': 3,
#   'operations': 3,
#   'problem solving': 3,
#   'troubleshooting': 3},
#  'Computer and Information Research Scientists': {'machine': 5,
#   'machine learning': 5,
#   'python': 3},
#  'Computer and Information Systems Managers': {'communication': 5,
#   'management': 5},
#  'Concierges': {'act': 5, 'communication': 5, 'level': 5, 'presentation': 5},
#  'Construction Carpenters': {'carpentry': 5,
#   'construction': 5,
#   'painting': 5,
#   'plumbing': 5,
#   'tiling': 5},
#  'Construction Laborers': {'construction': 5, 'cscs card': 5},
#  'Construction Managers': {'construction': 5, 'refurbishment': 5},
#  'Cooks, Institution and Cafeteria': {'cook': 5, 'hygiene': 5},
#  'Cooks, Restaurant': {'chef': 5,
#   'communication': 5,
#   'contamination': 5,
#   'cost control': 5,
#   'culinary arts': 5,
#   'hospitality': 5,
#   'hygiene': 5,
#   'legislation': 5,
#   'level': 5,
#   'production line': 5,
#   'security': 5},
#  'Correctional Officers and Jailers': {'agenda': 5,
#   'enthusiasm': 5,
#   'scale': 5},
#  'Cost Estimators': {'asset management': 5,
#   'collection': 5,
#   'communication': 5,
#   'construction': 5,
#   'continuous improvement process': 5,
#   'customer service': 5,
#   'drawing': 5,
#   'fabrication': 5,
#   'forecast': 5,
#   'health education': 5,
#   'laser': 5,
#   'lasers': 5,
#   'level': 5,
#   'management': 5,
#   'operations': 5,
#   'plan': 5,
#   'planning': 5,
#   'programming': 5,
#   'quantification': 5,
#   'quotations': 5,
#   'report writing': 5,
#   'sales': 5,
#   'scheme': 5,
#   'survey': 5,
#   'writing': 5},
#  'Counter Attendants, Cafeteria, Food Concession, and Coffee Shop': {'client confidentiality': 5,
#   'machine': 5},
#  'Criminal Investigators and Special Agents': {'communication': 5,
#   'decision making': 5,
#   'investigation': 5,
#   'legislation': 5,
#   'management': 5,
#   'plan': 5,
#   'research': 5,
#   'verbal communication skills': 5},
#  'Critical Care Nurses': {'act': 5,
#   'critical care': 5,
#   'management': 3,
#   'nursing': 3,
#   'registration': 3,
#   'rehabilitation': 5},
#  'Customer Service Representatives': {'acting': 3,
#   'bilingual': 3,
#   'communication': 4,
#   'customer service': 5,
#   'customer support': 3,
#   'level': 3,
#   'management': 3,
#   'profile': 3,
#   'sales': 3},
#  'Database Administrators': {'amazon web services': 3,
#   'cloud technologies': 3,
#   'data manipulation': 3,
#   'extract transform load': 3,
#   'management': 3,
#   'microsoft azure': 3,
#   'programming': 3,
#   'scale': 3,
#   'sql': 5,
#   'web services': 3},
#  'Dental Assistants': {'b': 5,
#   'c': 5,
#   'career development': 5,
#   'clinical practice': 5,
#   'closing': 5,
#   'consulting': 5,
#   'decontamination': 5,
#   'dentistry': 5,
#   'health policy': 5,
#   'hepatitis': 5,
#   'hepatitis b': 5,
#   'hepatitis c': 5,
#   'internet marketing': 5,
#   'leaflet': 5,
#   'machine': 5,
#   'marketing': 5,
#   'nursing': 5,
#   'oral health': 5,
#   'orthodontics': 5,
#   'plan': 5,
#   'radiation protection': 5,
#   'radiography': 5,
#   'registration': 5,
#   'rehabilitation': 5,
#   'social media': 5,
#   'surgery': 5,
#   'tuberculosis': 5},
#  'Dental Hygienists': {'level': 5, 'nursing': 5},
#  'Dental Laboratory Technicians': {'act': 5,
#   'communication': 5,
#   'construction': 5,
#   'head': 5,
#   'laboratory techniques': 5,
#   'level': 5,
#   'medical devices': 5,
#   'orthodontic': 5,
#   'orthodontics': 5,
#   'rehabilitation': 5,
#   'speech therapy': 5,
#   'surgery': 5,
#   'teaching': 5,
#   'technical services': 5},
#  'Diagnostic Medical Sonographers': {'closing': 5, 'leadership': 5},
#  'Dietetic Technicians': {'act': 5,
#   'audit': 5,
#   'communication': 5,
#   'dietetic': 5,
#   'rehabilitation': 5},
#  'Dietitians and Nutritionists': {'act': 5,
#   'communication': 3,
#   'dietetic': 5,
#   'dietetics': 3,
#   'rehabilitation': 5},
#  'Dining Room and Cafeteria Attendants and Bartender Helpers': {'advising': 5,
#   'career development': 5,
#   'customer service': 5,
#   'food service': 5},
#  'Driver/Sales Workers': {'communication': 5,
#   'customer service': 5,
#   'paperwork': 5},
#  'Editors': {'communication': 5,
#   'editing': 5,
#   'journalism': 5,
#   'linguistics': 5,
#   'proofreading': 5,
#   'translation': 5,
#   'writing': 5},
#  'Education Administrators, Elementary and Secondary School': {'leadership': 5,
#   'teaching': 5},
#  'Education Administrators, Postsecondary': {'administrative support': 5,
#   'analytical skills': 5,
#   'calendar': 5,
#   'communication': 5,
#   'customer service': 5,
#   'distance learning': 5,
#   'enthusiasm': 5,
#   'level': 5,
#   'management': 5,
#   'management system': 5,
#   'presentation': 5,
#   'presentation skills': 5,
#   'student services': 5,
#   'survey': 5,
#   'time management': 5},
#  'Education Administrators, Preschool and Childcare Center/Program': {'level': 5},
#  'Educational, Guidance, School, and Vocational Counselors': {'communication': 5,
#   'higher education': 5},
#  'Electrical Engineers': {'act': 3,
#   'avionics': 3,
#   'baseline': 3,
#   'bash': 3,
#   'biomass': 3,
#   'c': 3,
#   'closing': 3,
#   'commissioning': 3,
#   'communication': 4,
#   'electrical measurements': 3,
#   'electrical systems': 5,
#   'electronic': 3,
#   'java': 3,
#   'level': 4,
#   'pathfinder': 3,
#   'programming': 3,
#   'satellite assembly': 3,
#   'scripting': 3,
#   'simulation': 3,
#   'spacecraft': 3,
#   'support engineering': 3,
#   'telemetry': 3,
#   'test engineering': 3,
#   'test equipment': 3},
#  'Electricians': {'c': 5},
#  'Electronics Engineering Technicians': {'vinyl lettering': 5},
#  'Electronics Engineers, Except Computer': {'automotive engineering': 5,
#   'c': 5,
#   'electrical engineering': 5,
#   'electronics': 5,
#   'english language': 5,
#   'grade': 5,
#   'law enforcement': 5,
#   'mechanical engineering': 5,
#   'operation': 5,
#   'operations': 5,
#   'photography': 5,
#   'research': 5,
#   'telecommunications': 5,
#   'writing': 5},
#  'Emergency Medical Technicians and Paramedics': {'decision making': 3,
#   'disability': 3,
#   'paramedic': 5},
#  'Engineering Teachers, Postsecondary': {'level': 5, 'teaching': 5},
#  'Environmental Compliance Inspectors': {'communication': 5, 'management': 5},
#  'Environmental Engineers': {'audit': 5,
#   'legislation': 5,
#   'level': 5,
#   'management': 5},
#  'Environmental Science and Protection Technicians, Including Health': {'appraisals': 5,
#   'b': 5,
#   'c': 5,
#   'communication': 5,
#   'construction': 5,
#   'grade': 5,
#   'license': 5,
#   'management': 5,
#   'mould': 5,
#   'plan': 5,
#   'preparedness': 5,
#   'write': 5},
#  'Environmental Scientists and Specialists, Including Health': {'analytical chemistry': 5,
#   'analytical skills': 5,
#   'chemistry': 5,
#   'cleanrooms': 5,
#   'close': 5,
#   'environmental health': 5,
#   'environmental monitoring': 5,
#   'pharmaceutical': 5,
#   'pharmaceutical manufacturing': 5,
#   'research': 5,
#   'statistical analysis': 5,
#   'strong work ethic': 5},
#  'Epidemiologists': {'cohort studies': 5, 'epidemiology': 5},
#  'Equal Opportunity Representatives and Officers': {'emergency department': 5},
#  'Executive Secretaries and Executive Administrative Assistants': {'administrative support': 5,
#   'communication': 3,
#   'level': 3,
#   'management': 4,
#   'travel arrangements': 3},
#  'Family and General Practitioners': {'act': 3,
#   'management': 3,
#   'registration': 5,
#   'rehabilitation': 5},
#  'Farmers, Ranchers, and Other Agricultural Managers': {'communication': 5,
#   'decision making': 5,
#   'farm': 5,
#   'leadership': 5,
#   'management': 5,
#   'operations': 5},
#  'Financial Analysts': {'finance': 5, 'level': 5},
#  'Financial Examiners': {'m': 5,
#   'management': 5,
#   'property management': 5,
#   'r': 5,
#   'upselling': 5},
#  'Financial Managers, Branch or Department': {'budget': 3,
#   'cash flow': 3,
#   'communication': 5,
#   'finance': 5,
#   'investment': 3,
#   'ledger': 3,
#   'level': 3,
#   'management': 5,
#   'sales': 3},
#  'Fire-Prevention and Protection Engineers': {'auditing': 5,
#   'fire safety': 5,
#   'level': 5,
#   'quality assurance': 5,
#   'scheme': 5},
#  'First-Line Supervisors of Animal Husbandry and Animal Care Workers': {'audit': 3,
#   'auditing': 3,
#   'care management': 3,
#   'clinical nursing': 3,
#   'communication': 3,
#   'companionship': 3,
#   'customer service': 3,
#   'leadership': 3,
#   'learning development': 3,
#   'level': 5,
#   'literacy': 3,
#   'log': 3,
#   'management': 3,
#   'medication administration': 3,
#   'nursing': 3,
#   'paperwork': 3,
#   'peer': 3,
#   'peer support': 3,
#   'quality assurance': 3,
#   'record keeping': 3,
#   'reliability': 3,
#   'safe': 3,
#   'supervision': 3,
#   'track': 3,
#   'training documentation': 3,
#   'writing': 3},
#  'First-Line Supervisors of Construction Trades and Extraction Workers': {'budget': 5,
#   'civil engineering': 5,
#   'construction': 5,
#   'cscs card': 5,
#   'customer service': 5,
#   'electrical engineering': 5,
#   'level': 5,
#   'license': 5,
#   'm': 5,
#   'motivational skills': 5,
#   'plumbing': 5,
#   'plumbing systems': 5,
#   'scheme': 5,
#   'supervision': 5},
#  'First-Line Supervisors of Food Preparation and Serving Workers': {'chef': 4,
#   'communication': 3,
#   'head': 3,
#   'hygiene': 5},
#  'First-Line Supervisors of Mechanics, Installers, and Repairers': {'c': 5},
#  'First-Line Supervisors of Non-Retail Sales Workers': {'communication': 4,
#   'leadership': 3,
#   'management': 4,
#   'marketing': 3,
#   'sales': 5},
#  'First-Line Supervisors of Office and Administrative Support Workers': {'act': 3,
#   'bilingual': 3,
#   'brand': 3,
#   'communication': 5,
#   'customer service': 4,
#   'filing': 3,
#   'finance': 3,
#   'leadership': 3,
#   'level': 4,
#   'management': 5,
#   'microsoft office': 3,
#   'planning': 3,
#   'sales': 3,
#   'supervision': 3,
#   'track': 3},
#  'First-Line Supervisors of Production and Operating Workers': {'communication': 3,
#   'level': 3,
#   'management': 5},
#  'First-Line Supervisors of Retail Sales Workers': {'brand': 3,
#   'communication': 3,
#   'customer service': 5,
#   'leadership': 3,
#   'management': 3,
#   'merchandising': 3,
#   'sales': 5,
#   'stock': 3},
#  'First-Line Supervisors of Transportation and Material-Moving Machine and Vehicle Operators': {'communication': 5,
#   'warehouse': 5},
#  'Fitness Trainers and Aerobics Instructors': {'advise': 5,
#   'cleanliness': 5,
#   'communication': 5,
#   'customer service': 5,
#   'hygiene': 5,
#   'level': 5,
#   'perspective': 5},
#  'Food Batchmakers': {'acting': 5,
#   'catalyst': 5,
#   'level': 5,
#   'moulding': 5,
#   'quality procedures': 5,
#   'safe': 5,
#   'safety standards': 5,
#   'stock': 5,
#   'stock control': 5},
#  'Food Preparation Workers': {'safe': 5},
#  'Food Service Managers': {'allergens': 3,
#   'book': 3,
#   'budget': 3,
#   'business development': 3,
#   'chef': 3,
#   'cleanliness': 3,
#   'cooking': 3,
#   'food preparation': 3,
#   'head': 3,
#   'head start': 3,
#   'hygiene': 3,
#   'level': 3,
#   'management': 5,
#   'manual handling': 3,
#   'new business development': 3,
#   'requirements management': 3,
#   'safe': 3,
#   'stock': 3,
#   'stock rotation': 3,
#   'supply chain': 3,
#   'supply chain management': 3,
#   'teaching': 3},
#  'Fundraisers': {'fundraising': 5},
#  'General and Operations Managers': {'customer service': 3,
#   'leadership': 3,
#   'level': 3,
#   'management': 5,
#   'operations': 4,
#   'retail management': 3,
#   'sales': 4},
#  'Graphic Designers': {'adobe creative suite': 4,
#   'brand': 5,
#   'digital design': 5,
#   'head': 3,
#   'level': 3,
#   'marketing': 4},
#  'Health Diagnosing and Treating Practitioners, All Other': {'act': 5,
#   'rehabilitation': 5},
#  'Health Educators': {'act': 5,
#   'communication': 5,
#   'public health': 5,
#   'rehabilitation': 5},
#  'Health Specialties Teachers, Postsecondary': {'act': 5,
#   'close': 3,
#   'closing': 3,
#   'management': 3,
#   'rehabilitation': 3},
#  'Health Technologists and Technicians, All Other': {'communication': 5,
#   'dialysis': 5,
#   'kidney': 5,
#   'level': 5,
#   'machine': 5,
#   'management': 5,
#   'record keeping': 5,
#   'stock': 5},
#  'Healthcare Practitioners and Technical Workers, All Other': {'clinical assessment': 5,
#   'close': 5,
#   'communication': 5,
#   'coordinating': 5,
#   'histology': 5,
#   'kidney': 5,
#   'level': 5,
#   'nurse practitioner': 5,
#   'nursing': 5,
#   'pancreas': 5,
#   'registration': 5,
#   'surgery': 5,
#   'teaching': 5,
#   'track': 5,
#   'transplant': 5},
#  'Healthcare Social Workers': {'act': 3,
#   'communication': 4,
#   'disability': 3,
#   'level': 5,
#   'management': 3,
#   'nursing': 3,
#   'personal care': 4,
#   'rehabilitation': 3,
#   'smart device': 4},
#  'Healthcare Support Workers, All Other': {'act': 4,
#   'communication': 5,
#   'disabilities': 3,
#   'learning disabilities': 3,
#   'mental health': 3,
#   'nursing': 4,
#   'personal care': 4,
#   'rehabilitation': 3,
#   'safe': 3},
#  'Heavy and Tractor-Trailer Truck Drivers': {'license': 5,
#   'safe': 5,
#   'tachograph': 5},
#  'Home Health Aides': {'communication': 5,
#   'companionship': 4,
#   'compassion': 4,
#   'empathy': 4,
#   'level': 4,
#   'nursing': 5,
#   'personal care': 3,
#   'registered nurse': 3},
#  'Hospitalists': {'critical care': 5,
#   'energetic': 5,
#   'job planning': 5,
#   'leadership': 5,
#   'planning': 5,
#   'tenacity': 5},
#  'Hosts and Hostesses, Restaurant, Lounge, and Coffee Shop': {'hospitality': 5},
#  'Hotel, Motel, and Resort Desk Clerks': {'customer service': 5, 'level': 5},
#  'Human Factors Engineers and Ergonomists': {'budget': 5,
#   'creativity': 5,
#   'digital design': 5,
#   'enthusiasm': 5,
#   'governance': 5,
#   'innovation': 5,
#   'interaction design': 5,
#   'leadership': 5,
#   'perspective': 5,
#   'plan': 5,
#   'polishing': 5,
#   'project scope': 5,
#   'prototyping': 5,
#   'research': 5,
#   'resource': 5,
#   'revisions': 5,
#   'scale': 5,
#   'site maps': 5,
#   'thought leadership': 5,
#   'timelines': 5,
#   'usability': 5,
#   'user experience': 5,
#   'writing': 5},
#  'Human Resources Managers': {'coach': 3,
#   'employee relations': 4,
#   'learning development': 3,
#   'management': 5,
#   'plan': 3,
#   'resourcing': 3,
#   'tracking': 3},
#  'Human Resources Specialists': {'communication': 5,
#   'level': 3,
#   'management': 4,
#   'marketing': 3,
#   'social media': 3},
#  'Industrial Engineers': {'communication': 3,
#   'level': 4,
#   'management': 5,
#   'mechanical engineering': 3,
#   'quality management': 3},
#  'Industrial Production Managers': {'budget': 5,
#   'budgeting': 5,
#   'communication': 5,
#   'coordinating': 5,
#   'disciplinary procedures': 5,
#   'forecasting': 5,
#   'leadership': 5,
#   'management': 5,
#   'metallurgical engineering': 5,
#   'operating systems': 5,
#   'operation': 5,
#   'operations': 5,
#   'plan': 5,
#   'planning': 5,
#   'program development': 5,
#   'project management': 5,
#   'repair': 5,
#   'strategic planning': 5},
#  'Industrial Safety and Health Engineers': {'act': 3,
#   'auditing': 3,
#   'communication': 3,
#   'legislation': 4,
#   'level': 3,
#   'management': 5,
#   'safe': 3},
#  'Informatics Nurse Specialists': {'act': 5,
#   'clinical leadership': 5,
#   'inpatient care': 5,
#   'leadership': 5,
#   'machine': 5,
#   'management': 5,
#   'nice': 5,
#   'nursing': 5,
#   'operation': 5,
#   'primary care': 5,
#   'registered nurse': 5,
#   'rehabilitation': 5,
#   'secondary care': 5,
#   'zone': 5},
#  'Information Security Analysts': {'act': 5,
#   'altera quartus': 5,
#   'collaboration': 5,
#   'color': 5,
#   'communications': 5,
#   'cyber security': 5,
#   'design reviews': 5,
#   'disability': 5,
#   'head': 5,
#   'leadership': 5,
#   'level': 5,
#   'modelsim': 5,
#   'scheme': 5,
#   'security': 5,
#   'security clearance': 5,
#   'security technology': 5,
#   'simulation': 5,
#   'target platform': 5,
#   'team leadership': 5,
#   'technical design': 5,
#   'technical support': 5,
#   'tool': 5,
#   'vivado': 5},
#  'Information Technology Project Managers': {'communication': 4,
#   'leadership': 3,
#   'level': 4,
#   'management': 5,
#   'project management': 3,
#   'track': 3},
#  'Inspectors, Testers, Sorters, Samplers, and Weighers': {'cleanroom': 5,
#   'communication': 5,
#   'pharmaceutical': 5,
#   'product quality': 5,
#   'production schedule': 5},
#  'Instructional Coordinators': {'advising': 5,
#   'blogs': 5,
#   'level': 5,
#   'newsletters': 5,
#   'teaching': 5,
#   'welsh language': 5,
#   'workforce development': 5},
#  'Insurance Adjusters, Examiners, and Investigators': {'balance': 5,
#   'disability': 5,
#   'legislation': 5,
#   'registration': 5},
#  'Insurance Claims Clerks': {'claim resolution': 5,
#   'communication': 5,
#   'customer service': 5,
#   'financial services': 5,
#   'insurance product': 5,
#   'insurance products': 5,
#   'level': 5,
#   'literacy': 5,
#   'numeracy': 5,
#   'planning': 5},
#  'Insurance Sales Agents': {'communication': 5},
#  'Intelligence Analysts': {},
#  'Interior Designers': {'acting': 5,
#   'autocad': 5,
#   'bilingual': 5,
#   'client service': 5,
#   'communication': 5,
#   'coordinating': 5,
#   'customer service': 5,
#   'disability': 5,
#   'interior design': 5,
#   'level': 5,
#   'merchandising': 5,
#   'planning': 5,
#   'presentation': 5,
#   'sales': 5,
#   'sketch': 5,
#   'space planning': 5,
#   'visual merchandising': 5},
#  'Internists, General': {'act': 5,
#   'emergency medicine': 3,
#   'registration': 3,
#   'rehabilitation': 5,
#   'teaching': 3},
#  'Interpreters and Translators': {'communication': 3,
#   'level': 5,
#   'translation': 5},
#  'Interviewers, Except Eligibility and Loan': {'act': 5, 'rehabilitation': 5},
#  'Janitors and Cleaners, Except Maids and Housekeeping Cleaners': {'customer service': 3,
#   'license': 5,
#   'literacy': 3},
#  'Landscape Architects': {'adobe creative suite': 5,
#   'advise': 5,
#   'autocad': 5,
#   'design specification': 5,
#   'development management': 5,
#   'environmental design': 5,
#   'landscape': 5,
#   'landscape architecture': 5,
#   'landscape design': 5,
#   'level': 5,
#   'management': 5,
#   'plan': 5,
#   'planning': 5,
#   'presentation': 5,
#   'presentation skills': 5,
#   'presentations': 5,
#   'problem solving': 5,
#   'project management': 5,
#   'project proposals': 5},
#  'Landscaping and Groundskeeping Workers': {'gardening': 5},
#  'Lawyers': {'communication': 3,
#   'legislation': 3,
#   'management': 5,
#   'writing': 3},
#  'Legal Secretaries': {'acting': 5,
#   'administrative support': 5,
#   'arbitration': 5,
#   'banking': 5,
#   'bilingual': 5,
#   'booking': 5,
#   'communication': 5,
#   'communications': 5,
#   'disability': 5,
#   'editing': 5,
#   'finance': 5,
#   'international law': 5,
#   'management': 5,
#   'profile': 5,
#   'time management': 5,
#   'translation': 5,
#   'typing': 5,
#   'verbal communication skills': 5},
#  'Library Assistants, Clerical': {'adoption': 5,
#   'alternative technologies': 5,
#   'booking': 5,
#   'c': 5,
#   'cataloguing': 5,
#   'development study': 5,
#   'editing': 5,
#   'information literacy': 5,
#   'level': 5,
#   'library': 5,
#   'library management': 5,
#   'literacy': 5,
#   'management': 5,
#   'management system': 5,
#   'mobile devices': 5,
#   'problem solving': 5,
#   'r': 5,
#   'research': 5,
#   'revision': 5,
#   'social media': 5,
#   'stock': 5,
#   'study skills': 5,
#   'teaching': 5},
#  'Licensed Practical and Licensed Vocational Nurses': {'balance': 3,
#   'bank statement': 3,
#   'care planning': 3,
#   'clinical experience': 3,
#   'clinical leadership': 3,
#   'coach': 3,
#   'collection': 3,
#   'collections': 3,
#   'communication': 3,
#   'communications': 3,
#   'coordinate': 3,
#   'critical care': 3,
#   'customer service': 3,
#   'data collection': 3,
#   'dementia': 3,
#   'diplomacy': 3,
#   'direct patient care': 3,
#   'dot': 3,
#   'infection': 3,
#   'infection control': 3,
#   'infectious diseases': 3,
#   'information systems': 3,
#   'intradermal': 3,
#   'iv certification': 3,
#   'knowledge base': 3,
#   'leadership': 3,
#   'legislation': 3,
#   'level': 3,
#   'licensed practical nurse': 3,
#   'machine': 3,
#   'management': 3,
#   'medical records': 3,
#   'medical terminology': 3,
#   'medication administration': 3,
#   'nursing': 5,
#   'nursing care': 3,
#   'operations': 3,
#   'planning': 3,
#   'quality assurance': 3,
#   'quality control': 3,
#   'registered nurse': 3,
#   'safe': 4,
#   'scheme': 3,
#   'site assessment': 3,
#   'specimen collection': 3,
#   'storage': 3,
#   'supply inventory': 3,
#   'teaching': 3,
#   'triage': 3,
#   'urgent care': 3,
#   'venipuncture': 3,
#   'vital signs': 3,
#   'writing': 3},
#  'Light Truck or Delivery Services Drivers': {'communication': 5},
#  'Lodging Managers': {'act': 3,
#   'acting': 3,
#   'communication': 3,
#   'customer service': 3,
#   'guest relations': 3,
#   'interpersonal communication': 3,
#   'leadership': 3,
#   'level': 5,
#   'management': 3,
#   'management systems': 3,
#   'nursing': 3,
#   'nursing home': 3,
#   'office management': 3,
#   'operation': 3,
#   'operations': 3,
#   'property management': 3,
#   'property management systems': 3,
#   'registered nurse': 3,
#   'sales': 3,
#   'scheme': 3,
#   'selling techniques': 3,
#   'teamwork': 3},
#  'Logisticians': {'communication': 5, 'logistics': 5},
#  'Maids and Housekeeping Cleaners': {'cleanliness': 3,
#   'communication': 3,
#   'housekeeping': 5,
#   'safe': 4},
#  'Maintenance and Repair Workers, General': {'communication': 3,
#   'level': 5,
#   'repair': 3,
#   'safe': 4},
#  'Management Analysts': {'c': 3,
#   'communication': 5,
#   'consulting': 3,
#   'level': 5,
#   'management': 4,
#   'microsoft dynamics': 4,
#   'microsoft dynamics nav': 3,
#   'sql': 3},
#  'Managers, All Other': {'budget': 3,
#   'communication': 5,
#   'level': 3,
#   'management': 5,
#   'plan': 3,
#   'project management': 3},
#  'Market Research Analysts and Marketing Specialists': {'communication': 5,
#   'level': 4,
#   'management': 3,
#   'marketing': 4,
#   'profile': 3,
#   'research': 5},
#  'Marketing Managers': {'brand': 3,
#   'budget': 3,
#   'communication': 4,
#   'communications': 3,
#   'head': 3,
#   'leadership': 3,
#   'management': 5,
#   'marketing': 5,
#   'plan': 3,
#   'sales': 5,
#   'social media': 3},
#  'Marriage and Family Therapists': {'energetic': 5},
#  'Material Moving Workers, All Other': {'check cash': 5,
#   'collections': 5,
#   'communication': 5,
#   'customer service': 5,
#   'paperwork': 5},
#  'Mechanical Engineers': {'act': 3,
#   'advanced manufacturing': 3,
#   'boiler': 3,
#   'boilers': 3,
#   'calibration': 3,
#   'casting': 3,
#   'change requests': 3,
#   'cnc machining': 3,
#   'commissioning': 3,
#   'communication': 3,
#   'computer engineering': 3,
#   'cooling towers': 3,
#   'electronic': 4,
#   'engineering support': 3,
#   'fabrication': 3,
#   'goal set': 3,
#   'hvac': 3,
#   'industrial design': 3,
#   'innovation': 3,
#   'iosh managing safely': 3,
#   'laser': 3,
#   'level': 5,
#   'm': 3,
#   'machining': 3,
#   'management': 3,
#   'management system': 3,
#   'manufacturing engineering': 3,
#   'manufacturing processes': 3,
#   'mechanical design': 3,
#   'mechanical engineering': 3,
#   'metal fabrication': 3,
#   'microsoft certified systems engineer': 3,
#   'moulding': 3,
#   'operations': 3,
#   'planned maintenance': 3,
#   'product design': 3,
#   'product testing': 3,
#   'quotations': 3,
#   'radiology': 3,
#   'rehabilitation': 3,
#   'reliability': 3,
#   'repair': 3,
#   'revision': 3,
#   'safe': 3,
#   'sensor': 3,
#   'service level': 3,
#   'sheet metal': 3,
#   'solidworks': 3,
#   'surface': 3,
#   'type': 3,
#   'valve': 3,
#   'vibration': 3,
#   'water treatment': 3},
#  'Medical Assistants': {'act': 4,
#   'close': 3,
#   'comment': 3,
#   'communication': 5,
#   'level': 4,
#   'management': 3,
#   'nursing': 5,
#   'personal care': 3,
#   'phlebotomy': 3,
#   'rehabilitation': 4,
#   'safe': 3,
#   'supervision': 3,
#   'surgery': 3},
#  'Medical Equipment Preparers': {'decontamination': 5,
#   'surgical instruments': 3},
#  'Medical Equipment Repairers': {'act': 3,
#   'collection': 3,
#   'commissioning': 3,
#   'communication': 3,
#   'decontamination': 3,
#   'device management': 3,
#   'electrical safety': 3,
#   'electrical safety testing': 3,
#   'electronic': 3,
#   'hand tools': 3,
#   'level': 3,
#   'library': 3,
#   'life support': 3,
#   'literacy': 3,
#   'management': 3,
#   'medical device': 3,
#   'medical devices': 3,
#   'medical equipment': 5,
#   'numeracy': 3,
#   'planned maintenance': 3,
#   'preventive maintenance': 3,
#   'profile': 3,
#   'repair': 3,
#   'sepsis': 3,
#   'stock': 3,
#   'surface': 3,
#   'technical services': 3,
#   'technical support': 3,
#   'test equipment': 3},
#  'Medical Records and Health Information Technicians': {'head': 5,
#   'nursing': 5},
#  'Medical Scientists, Except Epidemiologists': {'act': 4,
#   'biochemistry': 3,
#   'biomedical science': 3,
#   'close': 3,
#   'communication': 4,
#   'histology': 3,
#   'laboratory experience': 4,
#   'level': 3,
#   'management': 4,
#   'microbiology': 3,
#   'pathology': 4,
#   'registration': 5,
#   'rehabilitation': 4,
#   'research': 4,
#   'supervision': 3,
#   'track': 3},
#  'Medical Secretaries': {'communication': 5, 'medical terminology': 3},
#  'Medical and Clinical Laboratory Technicians': {'level': 3,
#   'microbiology': 5,
#   'pathology': 3},
#  'Medical and Clinical Laboratory Technologists': {'communication': 5,
#   'electronic': 5,
#   'level': 5,
#   'management': 5,
#   'medical equipment': 5,
#   'physics': 5},
#  'Medical and Health Services Managers': {'act': 3,
#   'budget': 3,
#   'communication': 3,
#   'dementia': 3,
#   'leadership': 4,
#   'level': 3,
#   'management': 5,
#   'marketing': 3,
#   'nursing': 4,
#   'nursing care': 3,
#   'nursing home': 3,
#   'operation': 3,
#   'registered nurse': 3,
#   'registration': 3,
#   'regulatory requirements': 3,
#   'rehabilitation': 3,
#   'track': 3},
#  'Mental Health Counselors': {'act': 4,
#   'management': 3,
#   'mental health': 5,
#   'psychology': 3,
#   'registration': 3,
#   'rehabilitation': 3,
#   'supervision': 4},
#  'Mental Health and Substance Abuse Social Workers': {'act': 4,
#   'communication': 3,
#   'disabilities': 3,
#   'disability': 3,
#   'leadership': 3,
#   'level': 4,
#   'management': 4,
#   'mental health': 5,
#   'nursing': 3,
#   'registration': 3,
#   'rehabilitation': 4,
#   'supervision': 4},
#  'Microbiologists': {'b': 5, 'frame': 5, 'microbiology': 5, 'registration': 5},
#  'Midwives': {'act': 5, 'rehabilitation': 5},
#  'Nannies': {'companionship': 5, 'supervision': 5},
#  'Natural Sciences Managers': {'act': 5,
#   'agenda': 5,
#   'animal care': 5,
#   'library': 5,
#   'plan': 5},
#  'Network and Computer Systems Administrators': {'active directory': 3,
#   'communication': 5,
#   'customer service': 3,
#   'management': 5,
#   'operations': 4,
#   'planning': 3,
#   'scripting': 3,
#   'security': 3,
#   'sql': 3,
#   'storage': 3,
#   'troubleshooting': 3},
#  'Neurologists': {'act': 5, 'neurology': 5, 'rehabilitation': 5},
#  'Neuropsychologists and Clinical Neuropsychologists': {'act': 5,
#   'psychology': 5},
#  'Non-Destructive Testing Specialists': {'communication': 3,
#   'level': 5,
#   'organizational skills': 3},
#  'Nurse Midwives': {'act': 5, 'rehabilitation': 3},
#  'Nurse Practitioners': {'act': 5,
#   'communication': 3,
#   'leadership': 3,
#   'level': 5,
#   'management': 5,
#   'nurse practitioner': 5,
#   'nursing': 3,
#   'planning': 3,
#   'registration': 3,
#   'rehabilitation': 5},
#  'Nursery Workers': {'act': 5,
#   'child protection': 5,
#   'collection': 5,
#   'legislation': 5,
#   'level': 5,
#   'plan': 5,
#   'rehabilitation': 5,
#   'safe': 5},
#  'Nursing Assistants': {'act': 3,
#   'communication': 4,
#   'hygiene': 3,
#   'nursing': 5,
#   'personal care': 4,
#   'rehabilitation': 4,
#   'smart device': 3,
#   'supervision': 3},
#  'Nursing Instructors and Teachers, Postsecondary': {'child protection': 5,
#   'guarding': 5,
#   'leadership': 5,
#   'leadership development': 5,
#   'nursing': 5,
#   'profile': 5,
#   'research': 5,
#   'safe': 5},
#  'Obstetricians and Gynecologists': {'act': 5, 'rehabilitation': 5},
#  'Occupational Health and Safety Specialists': {'audit': 3,
#   'communication': 4,
#   'investigation': 3,
#   'legislation': 3,
#   'level': 3,
#   'management': 5,
#   'management systems': 3,
#   'microsoft office': 3,
#   'problem solving': 3,
#   'safe': 3},
#  'Occupational Health and Safety Technicians': {'audiometry': 5,
#   'blood pressure': 5,
#   'communication': 5,
#   'health screening': 5,
#   'urinalysis': 5},
#  'Occupational Therapists': {'act': 4,
#   'close': 3,
#   'communication': 4,
#   'disability': 3,
#   'leadership': 3,
#   'level': 3,
#   'management': 4,
#   'mental health': 3,
#   'planning': 3,
#   'registration': 4,
#   'rehabilitation': 5,
#   'supervision': 4},
#  'Occupational Therapy Assistants': {'act': 3,
#   'communication': 4,
#   'mental health': 3,
#   'rehabilitation': 5,
#   'supervision': 5},
#  'Office Clerks, General': {'typing': 5},
#  'Office and Administrative Support Workers, All Other': {'advising': 5,
#   'close': 5,
#   'floor': 5,
#   'knowledge base': 5,
#   'machine': 5,
#   'optics': 5,
#   'teaching': 5},
#  'Operations Research Analysts': {'detail oriented': 5,
#   'energetic': 5,
#   'microsoft dynamics': 5,
#   'microsoft dynamics nav': 5,
#   'problem solving': 5,
#   'process improvement': 5,
#   'salesforce': 5,
#   'software systems': 5,
#   'spreadsheets': 5,
#   'system support': 5},
#  'Ophthalmic Medical Technicians': {'angiography': 5,
#   'fluorescein angiography': 5,
#   'ophthalmology': 5},
#  'Ophthalmologists': {'act': 5, 'rehabilitation': 5},
#  'Opticians, Dispensing': {'sales': 5},
#  'Optometrists': {'clinical governance': 3, 'governance': 3, 'leadership': 5},
#  'Oral and Maxillofacial Surgeons': {'act': 5,
#   'registration': 5,
#   'rehabilitation': 5,
#   'security': 5},
#  'Order Clerks': {'sales': 5},
#  'Orthoptists': {'disability': 5, 'glaucoma': 5},
#  'Packaging and Filling Machine Operators and Tenders': {'engineering drawings': 5,
#   'machine': 5,
#   'mill': 5,
#   'programming': 5,
#   'technical engineering': 5,
#   'writing': 5},
#  'Painters, Construction and Maintenance': {'act': 5,
#   'decorating': 5,
#   'level': 5,
#   'paint': 5,
#   'painting': 5,
#   'refurbishment': 5,
#   'repair': 5,
#   'safe': 5,
#   'sand': 5,
#   'sealant': 5,
#   'steam cleaning': 5,
#   'surface': 5},
#  'Paralegals and Legal Assistants': {'communication': 5,
#   'investigation': 5,
#   'negligence': 5,
#   'scheduling': 5},
#  'Pathologists': {'act': 5,
#   'pathology': 5,
#   'registration': 5,
#   'rehabilitation': 5},
#  'Patient Representatives': {'book': 5,
#   'communication': 5,
#   'customer service': 5,
#   'job description': 5,
#   'level': 5,
#   'patient administration systems': 5,
#   'tracking': 5},
#  'Pediatricians, General': {'identity document': 5,
#   'machine': 5,
#   'registration': 5,
#   'security': 5,
#   'track': 5,
#   'zone': 5},
#  'Personal Care Aides': {'android': 3,
#   'comment': 3,
#   'dementia': 3,
#   'hygiene': 3,
#   'ipod touch': 3,
#   'level': 3,
#   'medication administration': 3,
#   'operating system': 3,
#   'personal care': 5,
#   'smart device': 3},
#  'Personal Financial Advisors': {'finance': 5},
#  'Pest Control Workers': {'legislation': 5,
#   'paperwork': 5,
#   'plan': 5,
#   'sales': 5},
#  'Pharmacists': {'act': 3,
#   'audit': 3,
#   'clinical pharmacy': 3,
#   'communication': 5,
#   'management': 4,
#   'operations': 4,
#   'pharmacy operations': 4,
#   'registration': 3,
#   'rehabilitation': 3},
#  'Pharmacy Technicians': {'advise': 3,
#   'collection': 3,
#   'counter': 4,
#   'level': 5,
#   'management': 3,
#   'operations': 3,
#   'pharmaceutical': 4,
#   'safe': 5},
#  'Phlebotomists': {'act': 5, 'phlebotomy': 5, 'rehabilitation': 5},
#  'Photographers': {'act': 5,
#   'clinical experience': 5,
#   'closing': 5,
#   'communication': 5,
#   'digital technology': 5,
#   'disability': 5,
#   'head': 5,
#   'image management': 5,
#   'level': 5,
#   'management': 5,
#   'ophthalmic photography': 5,
#   'photography': 5,
#   'scheme': 5,
#   'supervision': 5,
#   'timelines': 5},
#  'Physical Medicine and Rehabilitation Physicians': {'act': 5,
#   'close': 5,
#   'level': 5,
#   'management': 5,
#   'rehabilitation': 5},
#  'Physical Therapist Assistants': {'act': 5,
#   'communication': 5,
#   'rehabilitation': 5},
#  'Physical Therapists': {'act': 4,
#   'appraisal': 3,
#   'close': 3,
#   'communication': 4,
#   'disability': 3,
#   'level': 3,
#   'management': 4,
#   'registration': 4,
#   'rehabilitation': 5,
#   'supervision': 4,
#   'teaching': 3,
#   'track': 3},
#  'Physician Assistants': {'act': 3,
#   'communication': 5,
#   'nursing': 4,
#   'nursing home': 3},
#  'Physicians and Surgeons, All Other': {'act': 5,
#   'close': 3,
#   'emergency medicine': 3,
#   'level': 3,
#   'management': 3,
#   'registration': 3,
#   'rehabilitation': 5,
#   'research': 3,
#   'surgery': 3,
#   'teaching': 3},
#  'Physicists': {'brachytherapy': 5,
#   'collaboration': 5,
#   'commissioning': 5,
#   'dosimetry': 5,
#   'eclipse': 5,
#   'honesty': 5,
#   'oncology': 5,
#   'physics': 5,
#   'planning': 5,
#   'quality control': 5,
#   'safe': 5,
#   'skin': 5,
#   'skin treatments': 5,
#   'system support': 5,
#   'transformation': 5,
#   'treatment planning': 5,
#   'truebeam': 5,
#   'workmanship': 5},
#  'Plasterers and Stucco Masons': {'construction': 5,
#   'plastering': 5,
#   'repair': 5},
#  'Podiatrists': {'podiatry': 5, 'supervision': 3, 'surgery': 3},
#  'Preschool Teachers, Except Special Education': {'planning': 5},
#  'Production Workers, All Other': {'b': 5,
#   'drawing': 5,
#   'engineering drawing': 5,
#   'level': 5,
#   'machine': 5,
#   'mechanical seals': 5,
#   'n': 5,
#   'reliability': 5,
#   'safe': 5,
#   'source': 5},
#  'Production, Planning, and Expediting Clerks': {'communication': 5,
#   'management': 5,
#   'planning': 5,
#   'sales': 5,
#   'scheduling': 5},
#  'Property, Real Estate, and Community Association Managers': {'communication': 3,
#   'dementia': 3,
#   'level': 3,
#   'management': 5,
#   'marketing': 3,
#   'supervision': 3,
#   'track': 4},
#  'Psychiatric Technicians': {'appraisal': 5,
#   'clinical supervision': 5,
#   'level': 5,
#   'plan': 5,
#   'problem solving': 5,
#   'registration': 5,
#   'supervision': 5},
#  'Psychiatrists': {'act': 5,
#   'management': 3,
#   'mental health': 5,
#   'psychiatry': 3,
#   'registration': 4,
#   'rehabilitation': 4},
#  'Public Relations Specialists': {'communication': 3,
#   'communications': 5,
#   'management': 3,
#   'marketing': 3,
#   'social media': 5,
#   'writing': 3},
#  'Public Relations and Fundraising Managers': {'communications': 5,
#   'management': 3,
#   'research': 3,
#   'stakeholder engagement': 3},
#  'Purchasing Agents, Except Wholesale, Retail, and Farm Products': {'communication': 5,
#   'management': 3,
#   'purchasing': 3},
#  'Purchasing Managers': {'level': 5,
#   'management': 5,
#   'procurement': 5,
#   'reduction': 5,
#   'track': 5},
#  'Radiation Therapists': {'act': 5, 'physics': 5, 'rehabilitation': 5},
#  'Radiologic Technicians': {'act': 3,
#   'close': 3,
#   'mri': 3,
#   'nuclear medicine': 3,
#   'radiology': 5,
#   'rehabilitation': 3},
#  'Radiologic Technologists': {'act': 5,
#   'communication': 4,
#   'mammography': 3,
#   'management': 3,
#   'mri': 3,
#   'radiography': 3,
#   'radiology': 4,
#   'registration': 3,
#   'rehabilitation': 5},
#  'Radiologists': {'registration': 5, 'track': 5},
#  'Real Estate Sales Agents': {'sales': 5},
#  'Receptionists and Information Clerks': {'customer service': 5, 'filing': 3},
#  'Recreation Workers': {'act': 5,
#   'bind': 5,
#   'collection': 5,
#   'level': 5,
#   'rehabilitation': 5,
#   'team building': 5},
#  'Recreational Therapists': {'act': 5, 'rehabilitation': 5, 'supervision': 5},
#  'Registered Nurses': {'act': 4,
#   'android': 3,
#   'book': 3,
#   'care planning': 3,
#   'clinical practices': 3,
#   'close': 3,
#   'closing': 3,
#   'commenting': 3,
#   'communication': 4,
#   'dementia': 3,
#   'dementia care': 3,
#   'disabilities': 3,
#   'disability': 3,
#   'elderly care': 3,
#   'governance': 3,
#   'ipod touch': 3,
#   'leadership': 3,
#   'legislation': 3,
#   'level': 3,
#   'management': 4,
#   'mental health': 3,
#   'mentorship': 3,
#   'mobile app': 3,
#   'nursing': 5,
#   'nursing care': 3,
#   'nursing home': 3,
#   'operating system': 3,
#   'palliative care': 3,
#   'panda': 3,
#   'pharmaceutical': 3,
#   'plan': 3,
#   'planning': 3,
#   'registered nurse': 5,
#   'registration': 4,
#   'rehabilitation': 4,
#   'research': 3,
#   'safe': 4,
#   'scheme': 3,
#   'smart device': 3,
#   'supervision': 3,
#   'surgery': 3,
#   'teach': 3,
#   'teaching': 3,
#   'track': 3},
#  'Regulatory Affairs Managers': {'biotechnology': 5,
#   'collaboration': 5,
#   'communication': 5,
#   'm': 5,
#   'management': 5,
#   'mitigation': 5,
#   'pharmaceutical': 5,
#   'planning': 5,
#   'project management': 5,
#   'quality assurance': 5,
#   'regulatory affairs': 5,
#   'regulatory requirements': 5,
#   'research': 5,
#   'roll': 5,
#   'supply chain': 5,
#   'write': 5,
#   'writing': 5},
#  'Regulatory Affairs Specialists': {'advise': 5,
#   'brand': 5,
#   'clinical experience': 5,
#   'leadership': 5,
#   'medical affairs': 5,
#   'pharmaceutical': 5,
#   'registration': 5},
#  'Reporters and Correspondents': {'asset classes': 5,
#   'book': 5,
#   'coordinate': 5,
#   'dental care': 5,
#   'economics': 5,
#   'equities': 5,
#   'investment': 5,
#   'level': 5,
#   'management': 5,
#   'source': 5,
#   'write': 5},
#  'Reservation and Transportation Ticket Agents and Travel Clerks': {'acting': 5,
#   'customer service': 5,
#   'disability': 5,
#   'hospitality': 5,
#   'profile': 5},
#  'Respiratory Therapists': {'registration': 5, 'track': 3},
#  'Retail Salespersons': {'customer service': 3, 'sales': 5, 'stock': 3},
#  'Sales Engineers': {'communication': 5,
#   'marketing': 3,
#   'problem solving': 3,
#   'sales': 5,
#   'sales support': 3},
#  'Sales Managers': {'b': 3,
#   'brand': 3,
#   'business development': 3,
#   'close': 3,
#   'cold calling': 3,
#   'communication': 4,
#   'customer service': 3,
#   'level': 3,
#   'management': 4,
#   'marketing': 3,
#   'planning': 3,
#   'sales': 5,
#   'track': 3},
#  'Sales Representatives, Services, All Other': {'b': 4,
#   'communication': 3,
#   'level': 3,
#   'management': 3,
#   'marketing': 3,
#   'profile': 3,
#   'sales': 5},
#  'Sales Representatives, Wholesale and Manufacturing, Except Technical and Scientific Products': {'close': 3,
#   'customer service': 3,
#   'management': 3,
#   'sales': 5},
#  'Sales Representatives, Wholesale and Manufacturing, Technical and Scientific Products': {'c': 3,
#   'communication': 4,
#   'customer service': 4,
#   'management': 4,
#   'pharmaceutical': 3,
#   'presentation': 3,
#   'primary care': 3,
#   'problem solving': 3,
#   'sales': 5,
#   'time management': 3},
#  'School Psychologists': {'act': 3,
#   'mental health': 3,
#   'rehabilitation': 3,
#   'research': 5,
#   'supervision': 3},
#  'Secretaries and Administrative Assistants, Except Legal, Medical, and Executive': {'acting': 3,
#   'bilingual': 3,
#   'booking': 3,
#   'communication': 4,
#   'disability': 3,
#   'management': 5,
#   'sales': 3,
#   'typing': 3},
#  'Security Guards': {'communication': 5, 'safe': 5, 'security': 5},
#  'Self-Enrichment Education Teachers': {'communication': 5,
#   'communication planning': 5,
#   'customer service': 5,
#   'national pool lifeguard qualification': 5,
#   'planning': 5,
#   'swim': 5,
#   'swimming': 5,
#   'teaching': 5},
#  'Sheet Metal Workers': {'installation': 5},
#  'Skincare Specialists': {'close': 5,
#   'customer service': 5,
#   'head': 5,
#   'retail experience': 5,
#   'skin': 5,
#   'skin care': 5},
#  'Social Science Research Assistants': {'cognitive neuroscience': 5,
#   'collection': 5,
#   'data collection': 5,
#   'level': 5,
#   'neuropsychology': 5,
#   'neuroscience': 5,
#   'psychology': 5,
#   'research': 5,
#   'research experience': 5,
#   'survey': 5,
#   'translational research': 5,
#   'visual perception': 5},
#  'Social and Community Service Managers': {'act': 3,
#   'budget': 3,
#   'communication': 4,
#   'disabilities': 4,
#   'leadership': 4,
#   'learning disabilities': 3,
#   'level': 5,
#   'management': 5,
#   'planning': 3,
#   'quality assurance': 3,
#   'safe': 3,
#   'supervision': 3},
#  'Social and Human Service Assistants': {'act': 3,
#   'android': 3,
#   'comment': 3,
#   'communication': 4,
#   'disabilities': 4,
#   'disability': 3,
#   'ipod touch': 3,
#   'learning disabilities': 4,
#   'level': 4,
#   'management': 4,
#   'mental health': 4,
#   'nursing': 3,
#   'operating system': 3,
#   'personal care': 5,
#   'plan': 3,
#   'planning': 3,
#   'safe': 4,
#   'smart device': 4,
#   'supervision': 3},
#  'Software Developers, Applications': {'analytics': 3,
#   'automation': 3,
#   'big data': 3,
#   'c': 4,
#   'communication': 3,
#   'devops': 4,
#   'docker': 3,
#   'git': 3,
#   'java': 5,
#   'javascript': 4,
#   'kubernetes': 3,
#   'level': 4,
#   'linux': 3,
#   'management': 5,
#   'problem solving': 3,
#   'programming': 3,
#   'python': 5,
#   'software development': 3,
#   'sql': 4},
#  'Software Developers, Systems Software': {'management': 5},
#  'Software Quality Assurance Engineers and Testers': {'english language': 3,
#   'grammar': 3,
#   'level': 5,
#   'management': 3,
#   'script': 3,
#   'test script': 3},
#  'Speech-Language Pathologists': {'act': 3,
#   'communication': 5,
#   'management': 3,
#   'registration': 3,
#   'rehabilitation': 4,
#   'supervision': 4},
#  'Speech-Language Pathology Assistants': {'cancer': 5,
#   'clinical supervision': 5,
#   'communication': 5,
#   'head': 5,
#   'language disorders': 5,
#   'service development': 5,
#   'speech therapy': 5,
#   'supervision': 5,
#   'written english': 5},
#  'Statisticians': {'data management': 5,
#   'management': 5,
#   'r': 5,
#   'research': 5,
#   'supervision': 5},
#  'Stock Clerks- Stockroom, Warehouse, or Storage Yard': {'communication': 5,
#   'warehouse': 5},
#  'Storage and Distribution Managers': {'level': 5,
#   'logistics': 5,
#   'management': 5,
#   'operation': 5,
#   'warehouse': 5},
#  'Substance Abuse and Behavioral Disorder Counselors': {'communication': 5,
#   'license': 5,
#   'safe': 5},
#  'Surgeons': {'act': 4,
#   'general surgery': 3,
#   'level': 3,
#   'registration': 3,
#   'rehabilitation': 4,
#   'surgery': 5,
#   'teaching': 3},
#  'Surgical Technologists': {'act': 5,
#   'communication': 5,
#   'electronic': 5,
#   'employee benefits': 5,
#   'management': 5,
#   'rehabilitation': 5},
#  'Survey Researchers': {'acting': 5,
#   'bilingual': 5,
#   'cold calling': 5,
#   'communication': 5,
#   'disability': 5,
#   'level': 5,
#   'profile': 5,
#   'research': 5,
#   'research experience': 5,
#   'secondary research': 5},
#  'Surveyors': {'communication': 5,
#   'level': 5,
#   'management': 5,
#   'profile': 5,
#   'property management': 5,
#   'sales': 5,
#   'surveys': 5},
#  'Teacher Assistants': {'child protection': 5},
#  'Technical Writers': {'bid': 5,
#   'communication': 5,
#   'constructive feedback': 5,
#   'desktop publishing': 5,
#   'journalism': 5,
#   'library': 5,
#   'management': 5,
#   'peer': 5,
#   'peer review': 5,
#   'presentations': 5,
#   'project management': 5,
#   'research': 5,
#   'writing': 5,
#   'written english': 5},
#  'Telemarketers': {'sales': 5},
#  'Training and Development Managers': {'head': 3,
#   'health education': 3,
#   'level': 5},
#  'Training and Development Specialists': {'leadership': 4,
#   'learning development': 3,
#   'management': 5},
#  'Treasurers and Controllers': {'communication': 3,
#   'finance': 5,
#   'management': 3},
#  'Tutors': {'level': 5},
#  'Upholsterers': {'upholstery': 5},
#  'Veterinary Technologists and Technicians': {},
#  'Vocational Education Teachers, Postsecondary': {'rehabilitation': 5},
#  'Waiters and Waitresses': {'communication': 5},
#  'Web Developers': {'android': 3,
#   'angular': 3,
#   'c': 4,
#   'communication': 3,
#   'git': 3,
#   'java': 3,
#   'javascript': 5,
#   'jquery': 3,
#   'level': 3,
#   'management': 3,
#   'php': 3,
#   'research': 3,
#   'software development': 3,
#   'sql': 3}}

# %% [markdown]
# ## 4. Skills Gap Identification

# %% [markdown]
# Skills Gap Functions
#
# The following portion is our algorithm to idenitfy exactly how far the candidate is from obtaining their desired occupation.

# %%
# Map years of experience to competency level of either 3, 4 or 5
def user_level_deduction(years):
    if years <= 2:
        return 3
    elif years <= 5:
        return 4
    else:
        return 5

# return skills gap grouped by skills
def skills_gap_identification(skills, skills_required):
    diff = {}
    for key in skills_required:
        if key not in skills:
            diff[key] = [x for x in range(3, skills_required[key] + 1)]
        else:
            user_level = user_level_deduction(skills[key])
            if user_level < skills_required[key]:
                diff[key] = [x for x in range(user_level + 1, skills_required[key] + 1)]
    return diff

# %% [markdown]
# ### 4.1 Gaps between User and Job Requirements

# %%
with open('job_skills.pkl', 'rb') as pickle_file:
    job_skills = pickle.load(pickle_file)

with open('resume_skills.pkl', 'rb') as pickle_file:
    resume_skills = pickle.load(pickle_file)

with open('job_skills_required.pkl', 'rb') as pickle_file:
    job_skills_required = pickle.load(pickle_file)

skills_gap_jobs = skills_gap_identification(resume_skills[31605080], job_skills_required['Web Developers'])
skills_gap_jobs
# Out:
# {'angular': [3],
#  'c': [3, 4],
#  'git': [3],
#  'javascript': [3, 4, 5],
#  'php': [3],
#  'sql': [3]}

# %% [markdown]
# ### 4.2 Gaps between User and Other Candidates

# %% [markdown]
# We also added a portion that makes comparison between candidates as we believe that it is also crucial for the candidate to understand where he/she stands in the current market in order for them to obtain their desired occupation.

# %%
with open('resume_skills_required.pkl', 'rb') as pickle_file:
    resume_skills_required = pickle.load(pickle_file)

skills_gap_cand = skills_gap_identification(resume_skills[31605080], resume_skills_required['AVIATION'])
skills_gap_cand
# Out:
# {'aircraft maintenance': [3],
#  'ammunition': [3],
#  'aviation': [4, 5],
#  'b': [3],
#  'budget': [3],
#  'business administration': [3],
#  'c': [3],
#  'communication': [3, 4],
#  'communications': [3],
#  'control systems': [3],
#  'coordinate': [3],
#  'coordinating': [3],
#  'critical thinking': [3],
#  'data entry': [3],
#  'electronic': [3],
#  'electronics': [3],
#  'filing': [3],
#  'hydraulic': [3],
#  'inventory control': [3],
#  'leadership': [3, 4],
#  'level': [3, 4],
#  'license': [3],
#  'm': [3],
#  'machine': [3],
#  'management': [4, 5],
#  'marketing': [3],
#  'mechanic': [3],
#  'merchandise': [3],
#  'microsoft office': [3],
#  'operation': [3, 4],
#  'operations': [3, 4],
#  'paperwork': [3],
#  'plan': [3],
#  'planning': [3, 4],
#  'presentations': [3],
#  'process improvement': [3],
#  'procurement': [3],
#  'project management': [3],
#  'purchase': [3],
#  'purchasing': [3],
#  'quality assurance': [3],
#  'quality control': [3],
#  'r': [3],
#  'reduction': [3],
#  'repair': [3, 4],
#  'resource': [3],
#  'safety training': [3],
#  'sales': [3],
#  'scheduling': [3],
#  'security': [3, 4],
#  'security clearance': [3],
#  'spreadsheets': [3],
#  'stock': [3],
#  'storage': [3],
#  'supervision': [3],
#  'test equipment': [3],
#  'time management': [3],
#  'tool': [3],
#  'track': [3],
#  'tracking': [3],
#  'writing': [3]}

# %% [markdown]
# ## 5. Pathway Generation

# %% [markdown]
# Now that the gaps have been identified, it is time for us to generate a learning path of courses that the user can take in order for them to bridge it. There are 2 different methods used in this notebook, Dot2Vec and Spacy.

# %%
courses = pd.read_excel('Courses.xlsx')
courses = courses.fillna('')
courses['Description'] = courses['jobFamily'] + ' ' \
                         + courses['Marketing Name'] + ' ' \
                         + courses['courseName'] + ' ' \
                         + courses ['moduleName'] + ' ' \
                         + courses['courseDesc'] + ' ' \
                         + courses['Outcome Description'] +  ' ' \
                         + courses['competencyUnitDesc']
courses = courses[['productId', 'Marketing Name', 'Description', 'jobFamily', 'competencyLevel']]
courses['Description'] = courses['Description'].astype(str)
courses['Description'] = courses['Description'].apply(preprocess)

# %%
courses.jobFamily.value_counts()
# Out:
# Software Design & Development                 514
# Infocomm Sales & Marketing                    195
# Infrastructure Support                        105
# Business Analytics                            105
# Digital Advertising / Digital Distribution    100
# Infrastructure Architecture                    37
# Enterprise Mobility                            17
# Project Management                             16
# Strategy and Architecture                      15
# Service Innovation Design                      14
# Infocomm Security                              13
# Sales and Marketing                            12
# Cloud Computing                                 9
# Data Centre Management                          9
# Product Management                              7
# IT Management                                   5
# Enterprise Network Design Management            5
# IT Outsourcing Management                       1
# Generic Skills                                  1
# Name: jobFamily, dtype: int64

# %% [markdown]
# Functions

# %%
# group skills gap by level
def skills_gap_by_level(skills_gap):
    new_skills_gap = {}
    for skill in skills_gap:
        for level in skills_gap[skill]:
            if level in new_skills_gap:
                new_skills_gap[level].append(skill)
            else:
                new_skills_gap[level] = [skill]
    return new_skills_gap

# %% [markdown]
# ### 5.1 Doc2Vec

# %%
def tagcol_paragraph_embeddings_features(train_data):

    # Expects a dataframe with a 'Description' column
    train_data_values = train_data['Description'].values
    
    # Remember to use token.text to get the raw string, otherwise doc2vec cannot build vocabulary
    columns = [TaggedDocument([token.text for token in nlp(text) if token is not token.is_stop] , [i]) for i, text in enumerate(train_data_values)]
    
    return columns

corpus = tagcol_paragraph_embeddings_features(courses)
model = Doc2Vec(dm=0, vector_size=50, workers=multiprocessing.cpu_count(), min_count=2, epochs=100, hs=1, negative=0)
model.build_vocab(corpus)
model.train(corpus, total_examples=model.corpus_count, epochs=model.epochs)
# model.save("d2v_model.pkl")

# %% [markdown]
# Test Case

# %%
def course_suggestion_d2v(doc2vec_model, skills_gap_cand, skills_gap_jobs, courses_dataset):
    ans = {'job': {}, 'continuous learning': {}}

    for key in skills_gap_jobs:
        vector = doc2vec_model.infer_vector(skills_gap_jobs[key])
        res = doc2vec_model.dv.most_similar([vector], topn=20)
        course_unique = set()
        course_list = []
        for i, prob in res:
            if courses_dataset.loc[i, 'competencyLevel'][0] == str(key) and courses_dataset.loc[i, 'Marketing Name'] not in course_unique:
                course_unique.add(courses_dataset.loc[i, 'Marketing Name'])
                course_list.append((courses_dataset.loc[i, 'productId'], courses_dataset.loc[i, 'Marketing Name'], courses_dataset.loc[i, 'competencyLevel']))
        ans['job'][key] = course_list[:5]

    for key in skills_gap_cand:
        vector = doc2vec_model.infer_vector(skills_gap_cand[key])
        res = doc2vec_model.dv.most_similar([vector], topn=20)
        course_unique = set()
        course_list = []
        for i, prob in res:
            if courses_dataset.loc[i, 'competencyLevel'][0] == str(key) and courses_dataset.loc[i, 'Marketing Name'] not in course_unique:
                course_unique.add(courses_dataset.loc[i, 'Marketing Name'])
                course_list.append((courses_dataset.loc[i, 'productId'], courses_dataset.loc[i, 'Marketing Name'], courses_dataset.loc[i, 'competencyLevel']))
        ans['continuous learning'][key] = course_list[:5]

    return ans

# %%
course_suggestion_d2v(model, skills_gap_by_level(skills_gap_cand), skills_gap_by_level(skills_gap_jobs), courses)

# %% [markdown]
# ### 5.2 SpaCy

# %%
def course_suggestion_spacy(skills_gap_cand, skills_gap_jobs, courses_dataset):
    # load pre-trained model
    nlp = spacy.load('en_core_web_sm')
    ans = {'job': {}, 'continuous learning': {}}

    for level in skills_gap_jobs:
        skills_gap_text = " ".join(skills_gap_jobs[level])

        # get courses of same competency level
        df = courses_dataset[courses_dataset["competencyLevel"].str.contains(str(level))]

        # get similarity score
        df["Similarity"] = df["Description"].apply(lambda x: nlp(skills_gap_text).similarity(nlp(str(x))))
        top_courses = df.nlargest(20,'Similarity',keep='all')
        course_unique = set()
        course_list = []
        for index, row in top_courses.iterrows():
            if row['Marketing Name'] not in course_unique:
                course_unique.add(row['Marketing Name'])
                course_list.append((row['productId'], row['Marketing Name'], row['competencyLevel']))
        ans['job'][key] = course_list[:5]

    for level in skills_gap_cand:
        skills_gap_text = " ".join(skills_gap_cand[level])

        # get courses of same competency level
        df = courses_dataset[courses_dataset["competencyLevel"].str.contains(str(level))]

        # get similarity score
        df["Similarity"] = df["Description"].apply(lambda x: nlp(skills_gap_text).similarity(nlp(str(x))))
        top_courses = df.nlargest(20,'Similarity',keep='all')
        course_unique = set()
        course_list = []
        for index, row in top_courses.iterrows():
            if row['Marketing Name'] not in course_unique:
                course_unique.add(row['Marketing Name'])
                course_list.append((row['productId'], row['Marketing Name'], row['competencyLevel']))
        ans['continuous learning'][key] = course_list[:5]

    return ans

# %%
course_suggestion_spacy(model, skills_gap_by_level(skills_gap_cand), skills_gap_by_level(skills_gap_jobs), courses)

# %% [markdown]
# ## 6. Final Function

# %% [markdown]
# For the final portion, we complie all our functions into a single function and the final output from our model is a dictionary where the key is the competency level (3, 4 or 5) and the value is the recommended courses for the user at said skill level.
#
# Make sure that you have `all_skills_emsi.xlsx`, `Courses.xlsx`, `resume_skills_required.pkl`, `job_skills_required.pkl` and `d2v_model.pkl`, and a sample resume `11592605.pdf`

# %% [markdown]
# ### 6.1 Functions and Libraries Required

# %%
import gensim
import multiprocessing
import nltk
import numpy as np
import pandas as pd
import re
import sklearn
import spacy
import pickle

from gensim import corpora
import aspose.words as aw
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from sklearn.preprocessing import MultiLabelBinarizer
from spacy.tokenizer import Tokenizer

# %%
# load pre-trained model
nlp = spacy.load('en_core_web_sm')
# Tokenize words only with the whitespace rule
# N-grams will no longer be treated as 'N' and '-grams'
nlp.tokenizer = Tokenizer(nlp.vocab, token_match=re.compile(r'\S+').match)

def preprocess(txt):
    txt = txt.lower()
    # these must come first
    txt = re.sub('b\.\S*', '', txt) # remove all bachelor qualifications
    txt = re.sub('m\.\S*', '', txt) # remove all master qualifications
    # then these
    txt = txt.replace("'","").replace("’","") # remove apostrophes
    txt = re.sub('<.*?>',' ',txt) # remove <> tags
    txt = re.sub('http\S+\s*', ' ', txt)  # remove URLs
    txt = re.sub('RT|cc', ' ', txt)  # remove RT and cc
    txt = re.sub('#\S+', '', txt)  # remove hashtags
    txt = re.sub('@\S+', '  ', txt)  # remove mentions
    txt = re.sub('[^a-zA-Z]', ' ', txt) # Remove non-English characters
    txt = re.sub('\s+', ' ', txt)  # remove extra whitespace

    # tokenize word
    txt = nlp(txt)

    # remove stop words
    txt = [token.text for token in txt if not token.is_stop]

    return ' '.join(txt)

def n_grams(tokens, n):
    return [' '.join(tokens[i:i+n]) for i in range(len(tokens)-n+1)]

def generate_list_of_skills(text):
    nlp_text = nlp(text)

    # removing stop words and implementing word tokenization
    tokens = [token.text for token in nlp_text if not token.is_stop]
    # all the resume skills will be saved here
    skillset = []
        
    # check for one-grams (example: python)
    for token in tokens:
        skillset.append(token)
        
    # check for noun_chunks (example: machine learning)
    for token in nlp_text.noun_chunks:
        token = token.text.lower().strip()
        skillset.append(token)

    # check for N-grams that SpaCy missed in the noun_chuncks
    for n in range(2, 10):
        for token in n_grams(tokens, n):
            token = token.lower().strip()
            skillset.append(token)

    return skillset

def create_skills_api(skills_api_filename):
    skills_api = pd.read_excel(skills_api_filename)
    skills_api['name'] = skills_api['name'].apply(lambda x: re.sub("\W?\(.*?\)","",x))
    skills_api['name'] = skills_api['name'].apply(lambda x: x.strip().lower())
    skills_api['lemmatized_name'] = skills_api['name'].apply(lambda x: ' '.join([token.lemma_ for token in nlp(x)]))
    skills_api = set(skills_api['name']).union(set(skills_api['lemmatized_name']))
    return skills_api

def read_resume(resume_filename):
    resume = aw.Document(resume_filename)
    resume_string = resume.to_string(aw.SaveFormat.TEXT).split('\r\n')
    resume_string = ' '.join(resume_string[1:-3])
    return resume_string

def create_courses_dataset(courses_dataset_filename):
    courses = pd.read_excel(courses_dataset_filename)
    courses = courses.fillna("")
    courses['Description'] = courses['jobFamily'] + " " \
                            + courses['Marketing Name'] + " " \
                            + courses['courseName'] + " " \
                            + courses ['moduleName'] + " " \
                            + courses['courseDesc'] + " " \
                            + courses['Outcome Description'] + " " \
                            + courses['competencyUnitDesc']
    courses = courses[['productId', 'Marketing Name', 'Description', 'jobFamily', 'competencyLevel']]
    courses['Description'] = courses['Description'].astype(str)
    courses['Description'] = courses['Description'].apply(preprocess)
    return courses

def section_break(original_resume_text):
    pattern = r'\b[A-Z]+\b'
    res = list(re.finditer(pattern, original_resume_text))
    ans = []

    if len(res) == 0:
        ans.append(original_resume_text)
    elif len(res) == 1:
        ans.append(original_resume_text[res[0].span()[1]:])
    else:
        i = 1
        while i < len(res):
            ans.append(original_resume_text[res[i-1].span()[1]:res[i].span()[0]])
            i += 1
        ans.append(original_resume_text[res[i-1].span()[1]:])
    return ans

def extract_skills(resume_text, skills_api, clean=True):
    if clean == True:
        resume_text = preprocess(resume_text)
    
    skillset = set([i for i in set([i.lower() for i in generate_list_of_skills(resume_text)])])
    return skillset.intersection(skills_api)

def date_search(resume):
    ans = []

    # find all the date occurrence based on the regular expression
    pattern = r'(((Jan(uary)?|Feb(ruary)?|Mar(ch)?|Apr(il)?|May|Jun(e)?|Jul(y)?|Aug(ust)?|Sep(tember)?|Nov(ember)?|Dec(ember)?)|(\d{1,2}\s?\/){0,2}|(\d{1,2}\s?\-){0,2})\s?[-/ ]?\s?\d{4}?)|\bPresent\b|\bpresent\b|\bCurrent\b|\bcurrent\b'
    res = list(re.finditer(pattern, resume))

    if len(res) > 1:
        for ele in res:
            # this is to eradicate the results of having only year but without month
            if len(ele.group().strip()) > 5:
                ans.append([ele.start(), ele.end(), ele.group().strip()])

    res = []
    # Convert "present" and "current" to today's date
    for ele in ans:
        if ele[2].lower() == 'present' or ele[2].lower() == 'current':
            today = pd.to_datetime('today').date()
            ele[2] = today
            res.append(ele)
        else:
            # catch DateParse Error here
            try:
                day = pd.to_datetime(ele[2]).date()
                ele[2] = day
                res.append(ele)
            except :
                print('Cannot parse the date: ', ele[2])

    
    # all the date results are given in the form of [datetime_start_index, datetime_end_index, datetime]
    return res

def experience_tagging(date_list):
    i = 1
    cleaned_section = {}

    while i < len(date_list):

        prev = date_list[i-1]
        cur = date_list[i]
        
        if cur[0] < prev[1] + 10:
            # Taking ceiling of the year of experience
            key = ((cur[2] - prev[2]).days // 365) + 1
            
            # section starts at the (end index of the current date) + 1
            frm = cur[1]+1

            if i < len(date_list) - 1:
                # if there is another date that appears later, then the section will be until the start index of the next date
                until = date_list[i+1][0]
            else:
                # else the section will be until the end of the resume
                until = -1
            

            # Multiple projects with same year of experience, we do 'chaining' here
            if key in cleaned_section:
                cleaned_section[key].append((frm, until))
            else:
                cleaned_section[key] = [(frm, until)]
            i += 2

        else:

            # ignore the current date, possibly it is useless
            i += 1

    return cleaned_section

def skills_experience_level_identification(resume, skills_api, clean=True):
    res = {}
    sections = section_break(resume)

    for section in sections:
        date_list = date_search(section)
        experience_sec = experience_tagging(date_list)
        for key in experience_sec:
            for start, end in experience_sec[key]:
                skills_list = extract_skills(section[start:end], skills_api, clean)
                for ele in skills_list:
                    if ele not in res:
                        res[ele] = key
                    else:
                        res[ele] = max(key, res[ele])

    # for all the skills which do not have any level of experience, assign a default value of 1
    skills_list = extract_skills(resume, skills_api, True)
    for ele in skills_list:
        if ele not in res:
            res[ele] = 1

    return dict(sorted(res.items(), key = lambda x:x[1], reverse = True))

def find_significant_skills(agg_table):

    # gauge skill levels according to percentiles
    skills_required = {}
    for col in agg_table.columns:
        skills = agg_table[col][agg_table[col] > 0]

        # no skills extracted > skills required = empty dictionary
        if len(skills) == 0: 
            skills_required[col] = dict()
        
        # some skills extracted > skills required = some dictionary
        else:
            series = agg_table[col][agg_table[col] >= np.percentile(skills, 95)]

            # if all skills above 95th percentile have same frequency, then scale them to 1 (max)
            if len(series.unique()) == 1:
                scaled_series = series.apply(lambda x: 1)
            # if skills above 95th percentile have different frequency, then scale to values between 0 and 1
            else:
                scaled_series = series.apply(lambda x: (x - series.min()) / (series.max() - series.min()))

            # bin skills according to percentiles
            binned_series = scaled_series.apply(lambda x: 5 if x > 0.7 else 4 if x > 0.3 else 3)
            
            # convert series to dictionary form
            skills_required[col] = binned_series.to_dict()

    return skills_required

def get_significance_table(df,skills_dic):
    
    # creates a binary matrix indicating the presence of each skill
    df['Skills'] = df['ID'].apply(lambda x: list(skills_dic[x].keys()))
    mlb = MultiLabelBinarizer()
    table = pd.DataFrame(mlb.fit_transform(df['Skills']),
                         columns=mlb.classes_,
                         index=df['Skills'].index)
    
    # add category column as y
    y = df['Category']
    table['y'] = y

    # sum by category column and divide by total number of instances
    agg_table = table.groupby(['y']).sum()
    agg_table = agg_table.T / table.groupby(['y']).size()

    return agg_table

def extract_skills_frequency(job_text, skills_api, clean=True):
  if clean == True:
      job_text = preprocess(job_text)

  # get all skills
  skillset = [i.lower() for i in generate_list_of_skills(job_text)]

  # get frequency of each skill
  skillset_count = {}
  for skill in skillset:
    if skill in skills_api:
      if skill in skillset_count:
        skillset_count[skill] = skillset_count[skill] + 1
      else:
        skillset_count[skill] = 1
  
  return dict(sorted(skillset_count.items(), key = lambda x:x[1], reverse = True))

# Map years of experience to competency level
def user_level_deduction(years):
    if years <= 2:
        return 3
    elif years <= 5:
        return 4
    else:
        return 5

# return skills gap grouped by skills
def skills_gap_identification(skills, skills_required):
    diff = {}
    for key in skills_required:
        if key not in skills:
            diff[key] = [x for x in range(3, skills_required[key] + 1)]
        else:
            user_level = user_level_deduction(skills[key])
            if user_level < skills_required[key]:
                diff[key] = [x for x in range(user_level + 1, skills_required[key] + 1)]
    return diff

# group skills gap by level
def skills_gap_by_level(skills_gap):
    new_skills_gap = {}
    for skill in skills_gap:
        for level in skills_gap[skill]:
            if level in new_skills_gap:
                new_skills_gap[level].append(skill)
            else:
                new_skills_gap[level] = [skill]
    return new_skills_gap

def tagcol_paragraph_embeddings_features(train_data):

    # Expects a dataframe with a 'Description' column
    train_data_values = train_data['Description'].values
    
    # Remember to use token.text to get the raw string, otherwise doc2vec cannot build vocabulary
    columns = [TaggedDocument([token.text for token in nlp(text) if token is not token.is_stop] , [i]) for i, text in enumerate(train_data_values)]
    
    return columns

def course_suggestion_d2v(doc2vec_model, skills_gap_cand, skills_gap_jobs, courses_dataset):
    ans = {'job': {}, 'continuous learning': {}}

    for level in skills_gap_jobs:
        vector = doc2vec_model.infer_vector(skills_gap_jobs[level])
        res = doc2vec_model.dv.most_similar([vector], topn=20)
        course_unique = set()
        course_list = []
        for i, prob in res:
            if courses_dataset.loc[i, 'competencyLevel'][0] == str(level) and courses_dataset.loc[i, 'Marketing Name'] not in course_unique:
                course_unique.add(courses_dataset.loc[i, 'Marketing Name'])
                course_list.append((courses_dataset.loc[i, 'productId'], courses_dataset.loc[i, 'Marketing Name'], courses_dataset.loc[i, 'competencyLevel']))
        ans['job'][level] = course_list[:5]

    for level in skills_gap_cand:
        vector = doc2vec_model.infer_vector(skills_gap_cand[level])
        res = doc2vec_model.dv.most_similar([vector], topn=20)
        course_unique = set()
        course_list = []
        for i, prob in res:
            if courses_dataset.loc[i, 'competencyLevel'][0] == str(level) and courses_dataset.loc[i, 'Marketing Name'] not in course_unique:
                course_unique.add(courses_dataset.loc[i, 'Marketing Name'])
                course_list.append((courses_dataset.loc[i, 'productId'], courses_dataset.loc[i, 'Marketing Name'], courses_dataset.loc[i, 'competencyLevel']))
        ans['continuous learning'][level] = course_list[:5]

    return ans

def course_suggestion_spacy(skills_gap_cand, skills_gap_jobs, courses_dataset):
    # load pre-trained model
    nlp = spacy.load('en_core_web_sm')
    ans = {'job': {}, 'continuous learning': {}}

    for level in skills_gap_jobs:
        skills_gap_text = " ".join(skills_gap_jobs[level])

        # get courses of same competency level
        df = courses_dataset[courses_dataset["competencyLevel"].str.contains(str(level))]
        df = df.copy()

        # get similarity score
        df["Similarity"] = df["Description"].apply(lambda x: nlp(skills_gap_text).similarity(nlp(str(x))))
        top_courses = df.nlargest(20,'Similarity',keep='all')
        course_unique = set()
        course_list = []
        for index, row in top_courses.iterrows():
            if row['Marketing Name'] not in course_unique:
                course_unique.add(row['Marketing Name'])
                course_list.append((row['productId'], row['Marketing Name'], row['competencyLevel']))
        ans['job'][level] = course_list[:5]

    for level in skills_gap_cand:
        skills_gap_text = " ".join(skills_gap_cand[level])

        # get courses of same competency level
        df = courses_dataset[courses_dataset["competencyLevel"].str.contains(str(level))]
        df = df.copy()

        # get similarity score
        df["Similarity"] = df["Description"].apply(lambda x: nlp(skills_gap_text).similarity(nlp(str(x))))
        top_courses = df.nlargest(20,'Similarity',keep='all')
        course_unique = set()
        course_list = []
        for index, row in top_courses.iterrows():
            if row['Marketing Name'] not in course_unique:
                course_unique.add(row['Marketing Name'])
                course_list.append((row['productId'], row['Marketing Name'], row['competencyLevel']))
        ans['continuous learning'][level] = course_list[:5]

    return ans

# %% [markdown]
# ### 6.2 High-level Extraction for The Final Function

# %%
def final_course_suggestion_d2v(resume_text, skills_api, resume_skills_required_pickle, peer_industry, job_skills_required_pickle, job_name, doc2vec_model, courses_dataset, clean=True):
    """
    This function returns list of courses corresponding to different competency levels for both job requirements and continuous learning.

    Parameters
    ----------
    resume_text : string
        The extracted text from a resume.
    skills_api : set
        A set that contains all the recognized skills. Created based on EMSI skills API.
    resume_skills_required_pickle: dictionary
        A dictionary that stores all the good-to-have skills and the corresponding competency levels for each industry.
    peer_industry: string
        The industry that you want to compare yourself with. 
    job_skills_required_pickle: dictionary
        A dictionary that stores all the job specific skills and the corresponding competency levels for each role.
    job_name: string
        The particular role that applicants are applying to.
    doc2vec_model: doc2vec model
        The pretrained doc2vec model to compare the similarity between skills required and courses description
    courses_dataset: pd.DataFrame
        The dataset that contains all the information of courses. Provided by Sambaash
    clean: boolean
        The boolean that indicates whether we shall clean the text
      

    Returns
    -------
    dict (a nested dictionary that contains all the courses information)

    See Also
    --------
    final_course_suggestion_spacy : A similar method, but it used spacy pre-trained model instead of doc2vec model

    Examples
    --------
    >>> final_course_suggestion_d2v(resume_text, skills_api, resume_skills_required_pickle, 'INFORMATION-TECHNOLOGY', 
                        job_skills_required_pickle, 'Software Developers, Applications', doc2vec_model, courses_dataset, True)
    {'job': 
        {
            3: [(7203,'Innovation and Entrepreneurship Capstone','3 - Entrant Level'), ...],
            4: [(4602, 'Express Data Base Administrator', '4 - Specialist Level'), ...],
            5: [(12502, 'Cyber Security Management Capstone Project','5 - Expert Level'), ...]
        }
     'continuous learning':
        {
            3: [(7203,'Innovation and Entrepreneurship Capstone','3 - Entrant Level'), ...],
            4: [(4602, 'Express Data Base Administrator', '4 - Specialist Level'), ...],
            5: [(12502, 'Cyber Security Management Capstone Project','5 - Expert Level'), ...]
        }
    }
    """

    if peer_industry not in resume_skills_required_pickle:
        return 'Industry Not Found'
    if job_name not in job_skills_required_pickle:
        return 'Job Not Found'
    
    my_resume_skills = skills_experience_level_identification(resume_text, skills_api, clean)

    skills_gap_cand = skills_gap_by_level(skills_gap_identification(my_resume_skills, resume_skills_required_pickle[peer_industry]))
    skills_gap_jobs = skills_gap_by_level(skills_gap_identification(my_resume_skills, job_skills_required_pickle[job_name]))
    
    return course_suggestion_d2v(doc2vec_model, skills_gap_cand, skills_gap_jobs, courses_dataset)


def final_course_suggestion_spacy(resume_text, skills_api, resume_skills_required_pickle, peer_industry, job_skills_required_pickle, job_name, courses_dataset, clean=True):
    """
    This function returns list of courses corresponding to different competency levels for both job requirements and continuous learning.

    Parameters
    ----------
    resume_text : string
        The extracted text from a resume.
    skills_api : set
        A set that contains all the recognized skills. Created based on EMSI skills API.
    resume_skills_required_pickle: dictionary
        A dictionary that stores all the good-to-have skills and the corresponding competency levels for each industry.
    peer_industry: string
        The industry that you want to compare yourself with. 
    job_skills_required_pickle: dictionary
        A dictionary that stores all the job specific skills and the corresponding competency levels for each role.
    job_name: string
        The particular role that applicants are applying to.
    courses_dataset: pd.DataFrame
        The dataset that contains all the information of courses. Provided by Sambaash
    clean: boolean
        The boolean that indicates whether we shall clean the text
      

    Returns
    -------
    dict (a nested dictionary that contains all the courses information)

    See Also
    --------
    final_course_suggestion_d2v: A similar method, but it used doc2vec model instead of spacy pre-trained model

    Examples
    --------
    >>> final_course_suggestion_d2v(resume_text, skills_api, resume_skills_required_pickle, 'INFORMATION-TECHNOLOGY', 
                        job_skills_required_pickle, 'Software Developers, Applications', doc2vec_model, courses_dataset, True)
    {'job': 
        {
            3: [(7203,'Innovation and Entrepreneurship Capstone','3 - Entrant Level'), ...],
            4: [(4602, 'Express Data Base Administrator', '4 - Specialist Level'), ...],
            5: [(12502, 'Cyber Security Management Capstone Project','5 - Expert Level'), ...]
        }
     'continuous learning':
        {
            3: [(7203,'Innovation and Entrepreneurship Capstone','3 - Entrant Level'), ...],
            4: [(4602, 'Express Data Base Administrator', '4 - Specialist Level'), ...],
            5: [(12502, 'Cyber Security Management Capstone Project','5 - Expert Level'), ...]
        }
    }
    """
    
    if peer_industry not in resume_skills_required_pickle:
        return 'Industry Not Found'
    if job_name not in job_skills_required_pickle:
        return 'Job Not Found'
    
    my_resume_skills = skills_experience_level_identification(resume_text, skills_api, clean)

    skills_gap_cand = skills_gap_by_level(skills_gap_identification(my_resume_skills, resume_skills_required_pickle[peer_industry]))
    skills_gap_jobs = skills_gap_by_level(skills_gap_identification(my_resume_skills, job_skills_required_pickle[job_name]))
    
    return course_suggestion_spacy(skills_gap_cand, skills_gap_jobs, courses_dataset)

# %% [markdown]
# ### 6.3 Test Run

# %%
# %%time
skills_api = create_skills_api('all_skills_emsi.xlsx')
resume_text = read_resume('resume_5.pdf')
courses_dataset = create_courses_dataset('Courses.xlsx')

with open('job_skills_required.pkl', 'rb') as pickle_file:
    job_skills_required_pickle = pickle.load(pickle_file)

with open('resume_skills_required.pkl', 'rb') as pickle_file:
    resume_skills_required_pickle = pickle.load(pickle_file)

with open('d2v_model.pkl', 'rb') as pickle_file:
    doc2vec_model = pickle.load(pickle_file)
# Out:
# CPU times: total: 2min 33s
# Wall time: 3min 5s

# %%
# %%time
final_course_suggestion_d2v(resume_text, skills_api, resume_skills_required_pickle, 'INFORMATION-TECHNOLOGY', 
                        job_skills_required_pickle, 'Software Developers, Applications', doc2vec_model, courses_dataset, True)
# Out:
# CPU times: total: 141 ms
# Wall time: 184 ms
# {'job': {3: [(7203,
#     'Innovation and Entrepreneurship Capstone',
#     '3 - Entrant Level')],
#   4: [(4602, 'Express Data Base Administrator', '4 - Specialist Level'),
#    (5401, 'Express CRM (Salesforce)', '4 - Specialist Level'),
#    (12706, 'Data Analysis & Visualization', '4 - Specialist Level'),
#    (6506, 'Express CRM <p> (with Salesforce CRM) ', '4 - Specialist Level'),
#    (1302,
#     'Strategic Usage of Business Intelligence (SAP)',
#     '4 - Specialist Level')],
#   5: []},
#  'continuous learning': {3: [(2901,
#     'Capstone Project using Java (SF)',
#     '3 - Entrant Level'),
#    (12601, 'Digital Fluency', '3 - Entrant Level')],
#   4: [(13803,
#     'Applied Degree in Digital Business <p> Quest International University Perak',
#     '4 - Specialist Level'),
#    (12107,
#     'BBA Ecommerce Management <p> from Sage University, Indore',
#     '4 - Specialist Level'),
#    (13722,
#     'Applied Degree in Digital Business <p> Institut Teknologi Sains dan Kesehatan Sugeng Hartono',
#     '4 - Specialist Level'),
#    (11702,
#     'Bachelor of Digital Business (Honours) <P> from Wawasan Open University',
#     '4 - Specialist Level'),
#    (11902,
#     'BBA E-Commerce Management\xa0<p> from\xa0Sage University',
#     '4 - Specialist Level')],
#   5: [(12502,
#     'Cyber Security Management Capstone Project',
#     '5 - Expert Level')]}}

# %%
# %%time
final_course_suggestion_spacy(resume_text, skills_api, resume_skills_required_pickle, 'INFORMATION-TECHNOLOGY', 
                        job_skills_required_pickle, 'Software Developers, Applications', courses_dataset, True)
# Out:
# C:\Users\wongy\AppData\Local\Temp\ipykernel_20248\4023764682.py:359: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   df["Similarity"] = df["Description"].apply(lambda x: nlp(skills_gap_text).similarity(nlp(str(x))))
# C:\Users\wongy\AppData\Local\Temp\ipykernel_20248\4023764682.py:359: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   df["Similarity"] = df["Description"].apply(lambda x: nlp(skills_gap_text).similarity(nlp(str(x))))
# C:\Users\wongy\AppData\Local\Temp\ipykernel_20248\4023764682.py:359: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   df["Similarity"] = df["Description"].apply(lambda x: nlp(skills_gap_text).similarity(nlp(str(x))))
# C:\Users\wongy\AppData\Local\Temp\ipykernel_20248\4023764682.py:377: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   df["Similarity"] = df["Description"].apply(lambda x: nlp(skills_gap_text).similarity(nlp(str(x))))
# C:\Users\wongy\AppData\Local\Temp\ipykernel_20248\4023764682.py:377: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   df["Similarity"] = df["Description"].apply(lambda x: nlp(skills_gap_text).similarity(nlp(str(x))))
# C:\Users\wongy\AppData\Local\Temp\ipykernel_20248\4023764682.py:377: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   df["Similarity"] = df["Description"].apply(lambda x: nlp(skills_gap_text).similarity(nlp(str(x))))
# CPU times: total: 57.5 s
# Wall time: 1min
# {'job': {3: [(5001, 'Data Intelligence', '3 - Entrant Level'),
#    (7316, 'Front End Web Development', '3 - Entrant Level'),
#    (10110, 'Omnicom Sales & Marketing  ', '3 - Entrant Level'),
#    (1901, 'Web Development Foundations (SF)', '3 - Entrant Level'),
#    (7318, 'Web Development Foundations ', '3 - Entrant Level')],
#   4: [(4401, 'Data Analytics with Hadoop', '4 - Specialist Level'),
#    (9601,
#     'Applied Master in Analytics & Artificial  Intelligence',
#     '4 - Specialist Level'),
#    (13601, 'AWS - Restart Program\xa0\xa0', '4 - Specialist Level'),
#    (1306,
#     'Business Intelligence Queries & Reports (SAP)',
#     '4 - Specialist Level'),
#    (8705, 'Innovation Implementation Insights', '4 - Specialist Level')],
#   5: [(12502,
#     'Cyber Security Management Capstone Project',
#     '5 - Expert Level'),
#    (703, 'Business Process Engineering', '5 - Expert Level'),
#    (7401, 'NICF-Information System Professional (SF)', '5 - Expert Level'),
#    (9502, 'Digital Work Place', '5 - Expert Level'),
#    (1501, 'Digital Recruiter', '5 - Expert Level')]},
#  'continuous learning': {3: [(4801,
#     'Pearson BTEC Level 3 90-Credit Diploma in IT',
#     '3 - Entrant Level'),
#    (2120, 'Pearson Level 3 National Extended Diploma ', '3 - Entrant Level'),
#    (2121,
#     'Pearson BTEC Level 3 National Extended Diploma in Computing',
#     '3 - Entrant Level'),
#    (10109, ' Microsoft ERP Implementation ', '3 - Entrant Level'),
#    (10110, 'Omnicom Sales & Marketing  ', '3 - Entrant Level')],
#   4: [(14816, 'Process Automation Project', '4 - Specialist Level'),
#    (701, 'CRM Application (SAP)', '4 - Specialist Level'),
#    (9012,
#     'Professional Diploma in Innovation Management Implementation',
#     '4 - Specialist Level'),
#    (4103,
#     'Master of Business (Enterprise Resource Planning Systems) SD',
#     '4 - Specialist Level'),
#    (1718, 'Email & Content Marketing', '4 - Specialist Level')],
#   5: [(703, 'Business Process Engineering', '5 - Expert Level'),
#    (7401, 'NICF-Information System Professional (SF)', '5 - Expert Level'),
#    (12502, 'Cyber Security Management Capstone Project', '5 - Expert Level'),
#    (704, 'Express BI', '5 - Expert Level'),
#    (1754, 'Startup Primer', '5 - Expert Level')]}}
